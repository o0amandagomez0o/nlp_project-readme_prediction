# %%
import os
import json
from typing import Dict, List, Optional, Union, cast
import requests

from env import github_token, github_username

import acquire_zach as az
import wrangle as w

import numpy as np
import pandas as pd

# acquire
from requests import get
from bs4 import BeautifulSoup
from time import sleep
import os

# prepare
import unicodedata
import re
import json
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

# explore
from sklearn.model_selection import train_test_split
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# model
from pprint import pprint
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# # Use helper functions to acquire a list of url suffixes from all of Google's Github Repos

# %%
def get_githubpgs():
    """
    This function will create a list of all the url pages in the google repos section
    """
    urls = []
    for i in range(1,68):
        
        url = f'https://github.com/google?page={i}'
        urls.append(url)
    return urls

# %%
urls = get_githubpgs()

# %%
urls
# Out:
# ['https://github.com/google?page=1',
#  'https://github.com/google?page=2',
#  'https://github.com/google?page=3',
#  'https://github.com/google?page=4',
#  'https://github.com/google?page=5',
#  'https://github.com/google?page=6',
#  'https://github.com/google?page=7',
#  'https://github.com/google?page=8',
#  'https://github.com/google?page=9',
#  'https://github.com/google?page=10',
#  'https://github.com/google?page=11',
#  'https://github.com/google?page=12',
#  'https://github.com/google?page=13',
#  'https://github.com/google?page=14',
#  'https://github.com/google?page=15',
#  'https://github.com/google?page=16',
#  'https://github.com/google?page=17',
#  'https://github.com/google?page=18',
#  'https://github.com/google?page=19',
#  'https://github.com/google?page=20',
#  'https://github.com/google?page=21',
#  'https://github.com/google?page=22',
#  'https://github.com/google?page=23',
#  'https://github.com/google?page=24',
#  'https://github.com/google?page=25',
#  'https://github.com/google?page=26',
#  'https://github.com/google?page=27',
#  'https://github.com/google?page=28',
#  'https://github.com/google?page=29',
#  'https://github.com/google?page=30',
#  'https://github.com/google?page=31',
#  'https://github.com/google?page=32',
#  'https://github.com/google?page=33',
#  'https://github.com/google?page=34',
#  'https://github.com/google?page=35',
#  'https://github.com/google?page=36',
#  'https://github.com/google?page=37',
#  'https://github.com/google?page=38',
#  'https://github.com/google?page=39',
#  'https://github.com/google?page=40',
#  'https://github.com/google?page=41',
#  'https://github.com/google?page=42',
#  'https://github.com/google?page=43',
#  'https://github.com/google?page=44',
#  'https://github.com/google?page=45',
#  'https://github.com/google?page=46',
#  'https://github.com/google?page=47',
#  'https://github.com/google?page=48',
#  'https://github.com/google?page=49',
#  'https://github.com/google?page=50',
#  'https://github.com/google?page=51',
#  'https://github.com/google?page=52',
#  'https://github.com/google?page=53',
#  'https://github.com/google?page=54',
#  'https://github.com/google?page=55',
#  'https://github.com/google?page=56',
#  'https://github.com/google?page=57',
#  'https://github.com/google?page=58',
#  'https://github.com/google?page=59',
#  'https://github.com/google?page=60',
#  'https://github.com/google?page=61',
#  'https://github.com/google?page=62',
#  'https://github.com/google?page=63',
#  'https://github.com/google?page=64',
#  'https://github.com/google?page=65',
#  'https://github.com/google?page=66',
#  'https://github.com/google?page=67']

# %%
urls = ['https://github.com/google?page=1',
 'https://github.com/google?page=2',
 'https://github.com/google?page=3',
 'https://github.com/google?page=4',
 'https://github.com/google?page=5',
 'https://github.com/google?page=6',
 'https://github.com/google?page=7',
 'https://github.com/google?page=8',
 'https://github.com/google?page=10',
 'https://github.com/google?page=11',
 'https://github.com/google?page=12',
 'https://github.com/google?page=13',
 'https://github.com/google?page=14',
 'https://github.com/google?page=15',
 'https://github.com/google?page=16',
 'https://github.com/google?page=17',
 'https://github.com/google?page=18',
 'https://github.com/google?page=19',
 'https://github.com/google?page=20',
 'https://github.com/google?page=21',
 'https://github.com/google?page=22',
 'https://github.com/google?page=23',
 'https://github.com/google?page=24',
 'https://github.com/google?page=25',
 'https://github.com/google?page=27',
 'https://github.com/google?page=28',
 'https://github.com/google?page=29',
 'https://github.com/google?page=30',
 'https://github.com/google?page=31',
 'https://github.com/google?page=32',
 'https://github.com/google?page=33',
 'https://github.com/google?page=35',
 'https://github.com/google?page=36',
 'https://github.com/google?page=37',
 'https://github.com/google?page=39',
 'https://github.com/google?page=40',
 'https://github.com/google?page=41',
 'https://github.com/google?page=42',
 'https://github.com/google?page=43',
 'https://github.com/google?page=44',
 'https://github.com/google?page=45',
 'https://github.com/google?page=46',
 'https://github.com/google?page=47',
 'https://github.com/google?page=48',
 'https://github.com/google?page=49',
 'https://github.com/google?page=50']

# %%
len(urls)
# Out:
# 46

# %%
def make_soup(url):
    '''
    This helper function takes in a url and requests and parses HTML
    returning a soup object.
    '''
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
    response = get(url, headers=headers)    
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# %%
def get_repo_linksuffix():
    """
    This function will concat a base url with the repo suffix
    and create a list of all appended repo links on a single page.
    """
    
    repos = []
    
    for n in range(30):
        link_suffix = soup.find_all('a', itemprop='name codeRepository')[n].get('href')
        repos.append(link_suffix)
    return repos

# %%
repo_links = []

for url in urls[:34]:
    soup = make_soup(url)
    repos = get_repo_linksuffix()
    repo_links.append(repos)
    repo_links

# %%
len(repo_links)
# Out:
# 34

# %%
repo_links
# Out:
# [['/google/llvm-bazel',
#   '/google/paseos',
#   '/google/filament',
#   '/google/it-cert-automation-practice',
#   '/google/jax',
#   '/google/zx',
#   '/google/flatbuffers',
#   '/google/wikiloop-doublecheck',
#   '/google/closure-compiler',
#   '/google/iree',
#   '/google/nodejs-container-image-builder',
#   '/google/CFU-Playground',
#   '/google/pytype',
#   '/google/gvisor',
#   '/google/styleguide',
#   '/google/nomulus',
#   '/google/agi',
#   '/google/j2objc',
#   '/google/trax',
#   '/google/personfinder',
#   '/google/sentencepiece',
#   '/google/evcxr',
#   '/google/proto-quic',
#   '/google/bulkan',
#   '/google/XNNPACK',
#   '/google/autocxx',
#   '/google/model-viewer',
#   '/google/ksp',
#   '/google/rust_icu',
#   '/google/BIG-bench'],
#  ['/google/blockly',
#   '/google/pigweed',
#   '/google/blockly-samples',
#   '/google/web-stories-wp',
#   '/google/cssi-labs',
#   '/google/gfbuild-glslang',
#   '/google/glog',
#   '/google/martian',
#   '/google/exposure-notifications-private-analytics-ingestion',
#   '/google/GoogleUtilities',
#   '/google/ecclesia-machine-management',
#   '/google/ground-platform',
#   '/google/shaka-player',
#   '/google/turbinia',
#   '/google/gtm-session-fetcher',
#   '/google/ffn',
#   '/google/earthenterprise',
#   '/google/gin-config',
#   '/google/vscode-bigquery',
#   '/google/docsy-example',
#   '/google/privacy-sandbox-aggregation-service',
#   '/google/fonts',
#   '/google/clasp',
#   '/google/nearby-connections',
#   '/google/cadvisor',
#   '/google/create-service-account',
#   '/google/oss-fuzz',
#   '/google/dopamine',
#   '/google/closure-compiler-npm',
#   '/google/elements-sk'],
#  ['/google/fhir',
#   '/google/CommonLoopUtils',
#   '/google/dagger',
#   '/google/go-attestation',
#   '/google/uncertainty-baselines',
#   '/google/j2cl',
#   '/google/tf-quant-finance',
#   '/google/exposure-notifications-verification-server',
#   '/google/angular-directed-graph',
#   '/google/glazier',
#   '/google/perfetto',
#   '/google/error-prone',
#   '/google/xls',
#   '/google/edward2',
#   '/google/xctestrunner',
#   '/google/syzkaller',
#   '/google/site-kit-wp',
#   '/google/highway',
#   '/google/clusterfuzz',
#   '/google/closure-library',
#   '/google/clif',
#   '/google/orbit',
#   '/google/shaka-packager',
#   '/google/ml-metadata',
#   '/google/exposure-notifications-server',
#   '/google/github-owners-bot',
#   '/google/kotlin',
#   '/google/tink',
#   '/google/zazu',
#   '/google/stijl'],
#  ['/google/knative-gcp',
#   '/google/googet',
#   '/google/accompanist',
#   '/google/logger',
#   '/google/safevalues',
#   '/google/flogger',
#   '/google/gps_building_blocks',
#   '/google/boringssl',
#   '/google/clspv',
#   '/google/season-of-docs',
#   '/google/graphicsfuzz',
#   '/google/copybara',
#   '/google/homebrew-verible',
#   '/google/agi-dev-releases',
#   '/google/flax',
#   '/google/nsjail',
#   '/google/peoplemath',
#   '/google/kafel',
#   '/google/pprof-nodejs',
#   '/google/megalista',
#   '/google/timesketch',
#   '/google/starlark-go',
#   '/google/rrg',
#   '/google/conscrypt',
#   '/google/accname',
#   '/google/semantic-locators',
#   '/google/truth',
#   '/google/ExoPlayer',
#   '/google/typedoc-neo-theme',
#   '/google/go-github'],
#  ['/google/benchmark',
#   '/google/mdl-ref-apps',
#   '/google/binexport',
#   '/google/service-worker-detector',
#   '/google/data-layer-helper',
#   '/google/oss-fuzz-vulns',
#   '/google/node-fastify-auto-push',
#   '/google/dv360-api',
#   '/google/pack-n-play',
#   '/google/startup-os',
#   '/google/ground-android',
#   '/google/transmat',
#   '/google/android-fhir',
#   '/google/dart_cli_pkg',
#   '/google/llvm-premerge-checks',
#   '/google/voice-builder',
#   '/google/myanmar-tools',
#   '/google/oatts',
#   '/google/docsy',
#   '/google/go-jsonnet',
#   '/google/libphonenumber',
#   '/google/modernstorage',
#   '/google/shadertrap',
#   '/google/cloud-forensics-utils',
#   '/google/mtail',
#   '/google/cabbie',
#   '/google/go-cloud',
#   '/google/fuzzing',
#   '/google/osv',
#   '/google/eng-edu'],
#  ['/google/postcss-rename',
#   '/google/python-fire',
#   '/google/grr',
#   '/google/dart_cli_script',
#   '/google/qkeras',
#   '/google/ko',
#   '/google/starthinker',
#   '/google/tsec',
#   '/google/proto-lens',
#   '/google/gazoo-device',
#   '/google/or-tools',
#   '/google/kne',
#   '/google/incremental-dom',
#   '/google/fleetspeak',
#   '/google/pprof',
#   '/google/guava',
#   '/google/oauth2l',
#   '/google/data-transfer-project',
#   '/google/breakpad',
#   '/google/s2a-core',
#   '/google/deluca',
#   '/google/triage-party',
#   '/google/learn-oss-with-google',
#   '/google/go-tpm-tools',
#   '/google/auto',
#   '/google/crmint',
#   '/google/playhvz',
#   '/google/skywater-pdk-actions',
#   '/google/fedjax',
#   '/google/slo-generator'],
#  ['/google/inverting-proxy',
#   '/google/verible',
#   '/google/ruy',
#   '/google/draco',
#   '/google/earthengine-api',
#   '/google/tarpc',
#   '/google/iree-llvm-sandbox',
#   '/google/skia-buildbot',
#   '/google/capirca',
#   '/google/go-safeweb',
#   '/google/driblet',
#   '/google/transit',
#   '/google/sandboxed-api',
#   '/google/trillian-examples',
#   '/google/devlibrary',
#   '/google/mobly',
#   '/google/s2geometry',
#   '/google/built_value.dart',
#   '/google/go-containerregistry',
#   '/google/js-green-licenses',
#   '/google/WebFundamentals',
#   '/google/CodeCity',
#   '/google/reflectable.dart',
#   '/google/bamboo-soy',
#   '/google/cloudprober',
#   '/google/talkback',
#   '/google/neuroglancer',
#   '/google/fscrypt',
#   '/google/swiftlogfirecloud',
#   '/google/brotli'],
#  ['/google/ac-library.cr',
#   '/google/eleventy-high-performance-blog',
#   '/google/go-flow-levee',
#   '/google/apitools',
#   '/google/git-presubmit-linter',
#   '/google/earthengine-community',
#   '/google/flutter.widgets',
#   '/google/chartjs.dart',
#   '/google/ehr-predictions',
#   '/google/eventid-js',
#   '/google/argh',
#   '/google/tock-on-titan',
#   '/google/seqio',
#   '/google/skywater-pdk-libs-sky130_fd_sc_hd',
#   '/google/mediapipe',
#   '/google/wmt-mqm-human-evaluation',
#   '/google/bulkdozer-lite',
#   '/google/project-OCEAN',
#   '/google/gts',
#   '/google/lldb-eval',
#   '/google/souper',
#   '/google/fuzzbench',
#   '/google/digitalbuildings',
#   '/google/googletest',
#   '/google/open-location-code',
#   '/google/snappy',
#   '/google/k8s-digester',
#   '/google/GTMAppAuth',
#   '/google/GoogleAppMeasurement',
#   '/google/gofuzz'],
#  ['/google/speaker-id',
#   '/google/trillian',
#   '/google/pyvisionproductsearch',
#   '/google/certificate-transparency-go',
#   '/google/AFL',
#   '/google/osqp-cpp',
#   '/google/moveit',
#   '/google/gnostic',
#   '/google/flutter-desktop-embedding',
#   '/google/leveldb',
#   '/google/fledge-shim',
#   '/google/trimmed_match',
#   '/google/ghc-source-gen',
#   '/google/ml-compiler-opt',
#   '/google/omaha',
#   '/google/oculi',
#   '/google/mono_repo.dart',
#   '/google/making_with_ml',
#   '/google/dqm',
#   '/google/patents-public-data',
#   '/google/coding-with-chrome',
#   '/google/certificate-transparency-rfcs',
#   '/google/der-ascii',
#   '/google/libtrusttoken',
#   '/google/oboe',
#   '/google/tsunami-security-scanner-plugins',
#   '/google/skia',
#   '/google/bms-toolkit',
#   '/google/gopacket',
#   '/google/xtoproto'],
#  ['/google/triggerator',
#   '/google/virtual-authenticators-tab',
#   '/google/material-design-icons',
#   '/google/nixery',
#   '/google/argon',
#   '/google/alligator2',
#   '/google/schedviz',
#   '/google/desugar_jdk_libs',
#   '/google/goexpect',
#   '/google/common-sk',
#   '/google/eDistantObject',
#   '/google/EarlGrey',
#   '/google/skywater-pdk-libs-sky130_bag3_pr',
#   '/google/go-licenses',
#   '/google/skywater-pdk',
#   '/google/process_runner',
#   '/google/keytransparency',
#   '/google/jsonnet',
#   '/google/distributed_point_functions',
#   '/google/chive-prosody',
#   '/google/eidos-audition',
#   '/google/riegeli',
#   '/google/grr-doc',
#   '/google/jax-md',
#   '/google/google-ctf',
#   '/google/mweb-analysis-tools',
#   '/google/private-join-and-compute',
#   '/google/json5format',
#   '/google/bundletool',
#   '/google/blueprint'],
#  ['/google/gfbuild-amber',
#   '/google/gfbuild-llpc',
#   '/google/compile-testing',
#   '/google/eng-practices',
#   '/google/addlicense',
#   '/google/go-dap',
#   '/google/secrets-sync-action',
#   '/google/j2cl-protobuf',
#   '/google/errorprone-rest-plugin',
#   '/google/autofdo',
#   '/google/json_serializable.dart',
#   '/google/amber',
#   '/google/brotli-wheels',
#   '/google/pkcs11test',
#   '/google/UIforETW',
#   '/google/mysql-ripple',
#   '/google/vim-maktaba',
#   '/google/sanitizers',
#   '/google/cel-go',
#   '/google/riscv-dv',
#   '/google/DAPLink-port',
#   '/google/df-conformer',
#   '/google/lyra',
#   '/google/atheris',
#   '/google/gousb',
#   '/google/TaglessCRM',
#   '/google/zoekt',
#   '/google/android-emulator-container-scripts',
#   '/google/vim-coverage',
#   '/google/eme-encryption-scheme-polyfill'],
#  ['/google/android-lint-performance-probe',
#   '/google/visqol',
#   '/google/ide-perf',
#   '/google/apt-golang-s3',
#   '/google/TestParameterInjector',
#   '/google/OpenSK',
#   '/google/google-id-token',
#   '/google/ts-bridge',
#   '/google/extra-keyboards-for-chrome-os',
#   '/google/flutter.plugins',
#   '/google/gson',
#   '/google/googleapis.dart',
#   '/google/webdriver.dart',
#   '/google/mozc',
#   '/google/marl',
#   '/google/honggfuzz',
#   '/google/openhtf',
#   '/google/password-alert',
#   '/google/automl',
#   '/google/mechahamster',
#   '/google/gmail-oauth2-tools',
#   '/google/cargo-raze',
#   '/google/skywater-pdk-libs-sky130_fd_io',
#   '/google/skywater-pdk-libs-sky130_fd_pr',
#   '/google/skywater-pdk-libs-sky130_fd_sc_hdll',
#   '/google/skywater-pdk-libs-sky130_fd_sc_hs',
#   '/google/skywater-pdk-libs-sky130_fd_sc_hvl',
#   '/google/skywater-pdk-libs-sky130_fd_sc_ls',
#   '/google/skywater-pdk-libs-sky130_fd_sc_ms',
#   '/google/skywater-pdk-libs-sky130_fd_sc_lp'],
#  ['/google/report2bq',
#   '/google/secrets-gradle-plugin',
#   '/google/cbortree',
#   '/google/coapblaster',
#   '/google/struct2tensor',
#   '/google/strict-csp',
#   '/google/dv360-api-appsscript-samples',
#   '/google/gnxi',
#   '/google/git-appraise',
#   '/google/rdma-unit-test',
#   '/google/protobuf-gradle-plugin',
#   '/google/libaddressinput',
#   '/google/zetasql',
#   '/google/copr-sundry',
#   '/google/duet',
#   '/google/tacotron',
#   '/google/ga4-gtm-migration',
#   '/google/packetdrill',
#   '/google/shaderc',
#   '/google/live-transcribe-speech-engine',
#   '/google/play-unity-plugins',
#   '/google/shoptimizer',
#   '/google/coset',
#   '/google/highwayhash',
#   '/google/tsunami-security-scanner',
#   '/google/wire',
#   '/google/objax',
#   '/google/pullsheet',
#   '/google/perf_data_converter',
#   '/google/neural-tangents'],
#  ['/google/meterstick',
#   '/google/vulncode-db',
#   '/google/formal-ml',
#   '/google/badwolf',
#   '/google/cyanobyte',
#   '/google/kunit-docs',
#   '/google/codemirror.dart',
#   '/google/GoogleDataTransport',
#   '/google/github-release-retry',
#   '/google/cel-spec',
#   '/google/cpp-from-the-sky-down',
#   '/google/basis_universal',
#   '/google/winops',
#   '/google/aidl-language',
#   '/google/selinux-policy-languages',
#   '/google/sketch2ae',
#   '/google/grinder.dart',
#   '/google/google-api-objectivec-client-for-rest',
#   '/google/kctf',
#   '/google/shopping-markup',
#   '/google/assetMG',
#   '/google/pub_cache',
#   '/google/resultstoreui',
#   '/google/link-diver',
#   '/google/android-cuttlefish',
#   '/google/nginx-sxg-module',
#   '/google/webpackager',
#   '/google/mysteryofthreebots',
#   '/google/tweakr',
#   '/google/licensecheck'],
#  ['/google/semantic-release-replace-plugin',
#   '/google/spatial-media',
#   '/google/sagetv',
#   '/google/vector_math.dart',
#   '/google/picatrix',
#   '/google/codeworld',
#   '/google/charts',
#   '/google/vim-colorscheme-primary',
#   '/google/vimdoc',
#   '/google/alertmanager-irc-relay',
#   '/google/TensorNetwork',
#   '/google/gops',
#   '/google/jarjar',
#   '/google/cabal2bazel',
#   '/google/deepvariant',
#   '/google/ads-privacy',
#   '/google/.github',
#   '/google/fractribution',
#   '/google/vim-codefmt',
#   '/google/reflow-list',
#   '/google/aiyprojects-raspbian',
#   '/google/ffcc',
#   '/google/aiyprojects-raspbian-tools',
#   '/google/go-tpm',
#   '/google/android-emulator-webrtc',
#   '/google/asylo',
#   '/google/recaptcha',
#   '/google/go-querystring',
#   '/google/trillian-website',
#   '/google/bi-tempered-loss'],
#  ['/google/cppdap',
#   '/google/retriever_parsing',
#   '/google/custom-tab-groups',
#   '/google/intellij-gn-plugin',
#   '/google/kasan',
#   '/google/prog-edu-assistant-quizzes',
#   '/google/cpu_features',
#   '/google/localized-narratives',
#   '/google/usbinfo',
#   '/google/shaka-streamer',
#   '/google/turbine',
#   '/google/jimfs',
#   '/google/chrometracing',
#   '/google/generic-webdriver-server',
#   '/google/gfbuild-swiftshader',
#   '/google/java-monitoring-client-library',
#   '/google/autocjk',
#   '/google/cld3',
#   '/google/sa360-webquery-bigquery',
#   '/google/quiver-dart',
#   '/google/jsonapi',
#   '/google/double-conversion',
#   '/google/ngx_brotli',
#   '/google/rpmpack',
#   '/google/taqo-paco',
#   '/google/devx-tools',
#   '/google/pygtrie',
#   '/google/kmsan',
#   '/google/gf-layers',
#   '/google/fruit'],
#  ['/google/jsaction',
#   '/google/lecam-gan',
#   '/google/GCP-deployment-scripts-for-PI-Core',
#   '/google/pcbdl',
#   '/google/standard-payments',
#   '/google/TrustScore',
#   '/google/instrumentsToPprof',
#   '/google/capsicum-test',
#   '/google/security-research',
#   '/google/outrigger',
#   '/google/certificate-transparency-community-site',
#   '/google/slowjam',
#   '/google/tabletopaudio-action',
#   '/google/volley',
#   '/google/brunsli',
#   '/google/connectedappssdk',
#   '/google/uuid',
#   '/google/matched_markets',
#   '/google/dfdewey',
#   '/google/look-before-you-speak',
#   '/google/google-api-javascript-client',
#   '/google/scaaml',
#   '/google/caliper',
#   '/google/escapevelocity',
#   '/google/inject-common',
#   '/google/guava-beta-checker',
#   '/google/web-serial-polyfill',
#   '/google/gsocguides',
#   '/google/wuffs-mirror-release-c',
#   '/google/stenographer'],
#  ['/google/google-drive-dokany',
#   '/google/applied-machine-learning-intensive',
#   '/google/nucleus',
#   '/google/google-toolbox-for-mac',
#   '/google/tirg',
#   '/google/webauthndemo',
#   '/google/source_helper.dart',
#   '/google/codesearch',
#   '/google/libsxg',
#   '/google/autobidding-readiness-monitor',
#   '/google/deepmac',
#   '/google/centaur',
#   '/google/mediapy',
#   '/google/platform.dart',
#   '/google/multichase',
#   '/google/git-appraise-web',
#   '/google/gfbuild-graphicsfuzz',
#   '/google/GTXiLib',
#   '/google/react-schemaorg',
#   '/google/licenseclassifier',
#   '/google/merror',
#   '/google/santa-tracker-web',
#   '/google/framework-for-osdu',
#   '/google/schema-dts',
#   '/google/actions-on-google-flashcards-template-sdk',
#   '/google/actions-on-google-trivia-template-sdk',
#   '/google/rejoiner',
#   '/google/jse4conf',
#   '/google/splot-java',
#   '/google/MOE'],
#  ['/google/cel-cpp',
#   '/google/allocation-instrumenter',
#   '/google/hotel-booking-api-validator',
#   '/google/wikiloop-explorer',
#   '/google/tamperchrome',
#   '/google/sqlcommenter',
#   '/google/web-starter-kit',
#   '/google/iconvg',
#   '/google/node-gles',
#   '/google/googlesource-auth-tools',
#   '/google/cctz',
#   '/google/chicago-brick',
#   '/google/ngrx-visualizer',
#   '/google/starlark-rust',
#   '/google/emoji-scavenger-hunt',
#   '/google/nanopb-podspec',
#   '/google/pawn',
#   '/google/vxsig',
#   '/google/vim-ft-go',
#   '/google/protodatastore-cpp',
#   '/google/python-spanner-orm',
#   '/google/web-api-gateway',
#   '/google/ml_collections',
#   '/google/code-review-bot',
#   '/google/model_search',
#   '/google/upvote',
#   '/google/huproxy',
#   '/google/bband-adaband',
#   '/google/re2j',
#   '/google/vim-jsonnet'],
#  ['/google/cm360-audience-manager',
#   '/google/memcpy-gemm',
#   '/google/process.dart',
#   '/google/brain-tokyo-workshop',
#   '/google/exposure-notifications-android',
#   '/google/csp-evaluator',
#   '/google/go-pcie-tlp',
#   '/google/dspl',
#   '/google/observable',
#   '/google/pinject',
#   '/google/wasserstein-dist',
#   '/google/har-sanitizer',
#   '/google/dotty',
#   '/google/gtest-parallel',
#   '/google/dart-basics',
#   '/google/go-intervals',
#   '/google/exposure-notifications-internals',
#   '/google/CausalImpact',
#   '/google/go-pcie-screamer',
#   '/google/sge-monorepo',
#   '/google/nsscache',
#   '/google/sa360-bigquery-bootstrapper',
#   '/google/monster-mash',
#   '/google/plusfish',
#   '/google/pasta',
#   '/google/ldif',
#   '/google/gov-meetings-made-searchable',
#   '/google/opendocs',
#   '/google/prefab',
#   '/google/material-design-lite'],
#  ['/google/bazel-common',
#   '/google/xsecurelock',
#   '/google/dart-json_diff',
#   '/google/archive-patcher',
#   '/google/paragraph',
#   '/google/http_pattern_matcher',
#   '/google/vulkan_test_applications',
#   '/google/ansicolor-dart',
#   '/google/youtube-8m',
#   '/google/brailleback',
#   '/google/flexbox-layout',
#   '/google/ctfscoreboard',
#   '/google/btree',
#   '/google/myelin-acorn-electron-hardware',
#   '/google/hubvantage',
#   '/google/webcrypto.dart',
#   '/google/shaderc-rs',
#   '/google/adb-sync',
#   '/google/uVkCompute',
#   '/google/fusion-tables-drive-export',
#   '/google/gfbuild-shadertrap',
#   '/google/example_extrapolation',
#   '/google/security-research-pocs',
#   '/google/tuple.dart',
#   '/google/gfbuild-SPIRV-Tools',
#   '/google/cel-policy-templates-go',
#   '/google/safehtml',
#   '/google/gnostic-grpc',
#   '/google/oss-vulnerability-guide',
#   '/google/ga360-bqml-toolkit'],
#  ['/google/corpuscrawler',
#   '/google/cocoapods-size',
#   '/google/bongo',
#   '/google/software-product-sprint',
#   '/google/pytruth',
#   '/google/android-emulator-m1-preview',
#   '/google/mathsteps',
#   '/google/nitroml',
#   '/google/fusion-tables-archive-visualizer',
#   '/google/poseshield-tfjs',
#   '/google/fhir-examples',
#   '/google/ms-tpm-20-ref',
#   '/google/aistplusplus_dataset',
#   '/google/x509test',
#   '/google/neural-light-transport',
#   '/google/digitalassetlinks',
#   '/google/svcca',
#   '/google/jwt_verify_lib',
#   '/google/uri.dart',
#   '/google/diff-match-patch',
#   '/google/google-my-business-samples',
#   '/google/aistplusplus_api',
#   '/google/perforce-utils',
#   '/google/file-based-test-driver',
#   '/google/pedantic',
#   '/google/eslint-config-google',
#   '/google/flight-lab',
#   '/google/carfac',
#   '/google/robotstxt',
#   '/google/language-jsonnet'],
#  ['/google/vk_callback_swapchain',
#   '/google/GiftStick',
#   '/google/santa-tracker-android',
#   '/google/binja-hexagon',
#   '/google/webkit_inspection_protocol.dart',
#   '/google/jsinterop-annotations',
#   '/google/jsinterop-base',
#   '/google/jsinterop-generator',
#   '/google/elemental2',
#   '/google/gps-measurement-tools',
#   '/google/ion',
#   '/google/platform_benchmarks',
#   '/google/simhospital',
#   '/google/arrow-logo',
#   '/google/stm32_bare_lib',
#   '/google/new-project',
#   '/google/aukera',
#   '/google/empirical_calibration',
#   '/google/kati',
#   '/google/node-h2-auto-push',
#   '/google/webrisk',
#   '/google/usbmon',
#   '/google/timecast',
#   '/google/quic-trace',
#   '/google/google-authenticator-libpam',
#   '/google/vimscript-language-server',
#   '/google/vroom',
#   '/google/smbios-validation-tool',
#   '/google/fleetspeak-rs',
#   '/google/schemarama'],
#  ['/google/redgrep',
#   '/google/mobly-bundled-snippets',
#   '/google/ormolu',
#   '/google/file.dart',
#   '/google/hdrnet',
#   '/google/asylo-site',
#   '/google/asylo-examples',
#   '/google/tcav-for-ehr',
#   '/google/neper',
#   '/google/dicomproxy',
#   '/google/idaidle',
#   '/google/play-licensing',
#   '/google/feedloader',
#   '/google/quiver-log',
#   '/google/forklift',
#   '/google/deepdream',
#   '/google/webbundle',
#   '/google/iosched',
#   '/google/prog-edu-assistant',
#   '/google/GSCXScanner',
#   '/google/acai',
#   '/google/java-photoslibrary',
#   '/google/ftc-object-detection',
#   '/google/macops',
#   '/google/re2-wasm',
#   '/google/language-resources',
#   '/google/tsunami',
#   '/google/cronutils',
#   '/google/crc32c',
#   '/google/fscryptctl'],
#  ['/google/tensorstore',
#   '/google/google-drive-proxy',
#   '/google/yt-3ds-wk',
#   '/google/zeroshell-linode',
#   '/google/audio-to-tactile',
#   '/google/gwtmockito',
#   '/google/zopfli',
#   '/google/proto-task-queue',
#   '/google/creative-screenshots',
#   '/google/apis-client-generator',
#   '/google/testimony',
#   '/google/docker-explorer',
#   '/google/gae-secure-scaffold-python',
#   '/google/nogotofail',
#   '/google/shenzhen-go',
#   '/google/prefetchalyzer',
#   '/google/crclib.dart',
#   '/google/compare-codecs',
#   '/google/web-hv',
#   '/google/multichannel-audio-tools',
#   '/google/rust-async-coap',
#   '/google/aichoreographer',
#   '/google/dart-gl',
#   '/google/network-mapper',
#   '/google/mako',
#   '/google/sling',
#   '/google/tie',
#   '/google/citest',
#   '/google/pwlfit',
#   '/google/go-metrics-stackdriver'],
#  ['/google/splice',
#   '/google/securemessage',
#   '/google/caliban',
#   '/google/pageloader',
#   '/google/lkml-gerrit-bridge',
#   '/google/zuckerli',
#   '/google/dv360-automation',
#   '/google/spindle-dv360',
#   '/google/canvas-5-polyfill',
#   '/google/vpn-libraries',
#   '/google/trueview-sdf-generator',
#   '/google/lisp-koans',
#   '/google/mannequinchallenge',
#   '/google/html-quiz',
#   '/google/lintush',
#   '/google/skicka',
#   '/google/ios-webkit-debug-proxy',
#   '/google/cauliflowervest',
#   '/google/importlab',
#   '/google/cdep',
#   '/google/emboss',
#   '/google/gemmlowp',
#   '/google/unsmear',
#   '/google/vsaq',
#   '/google/spirv-tutor',
#   '/google/StrawNet',
#   '/google/periph',
#   '/google/retiming',
#   '/google/google.github.io',
#   '/google/aistreams'],
#  ['/google/ci_edit',
#   '/google/hotels-template-library',
#   '/google/safeside',
#   '/google/ads-account-structure-script',
#   '/google/blockly-ios',
#   '/google/makani',
#   '/google/android-emulator-hypervisor-driver-for-amd-processors',
#   '/google/swift-jupyter',
#   '/google/open-gantry',
#   '/google/python-adb',
#   '/google/pybadges',
#   '/google/note-maps',
#   '/google/nftables',
#   '/google/swift',
#   '/google/kf',
#   '/google/php-photoslibrary',
#   '/google/coursebuilder-core',
#   '/google/tangent',
#   '/google/gitiles',
#   '/google/hypebot',
#   '/google/intermock',
#   '/google/python_portpicker',
#   '/google/lovefield',
#   '/google/python-lakeside',
#   '/google/path-auditor',
#   '/google/device-access-sample-web-app',
#   '/google/xscreensaver-dbus',
#   '/google/go-cmdtest',
#   '/google/tim-gan',
#   '/google/blockbuster'],
#  ['/google/tensorflow-recorder',
#   '/google/android-classyshark',
#   '/google/coding-with-chrome-libraries',
#   '/google/dnsmasq_exporter',
#   '/google/go-tika',
#   '/google/shaka-player-embedded',
#   '/google/crfs',
#   '/google/swift-structural',
#   '/google/spherical-harmonics',
#   '/google/latexify_py',
#   '/google/tcli',
#   '/google/hammer-kit',
#   '/google/openrtb',
#   '/google/spatiotemporal-graphnn-tf',
#   '/google/reftable',
#   '/google/usd_from_gltf',
#   '/google/ubntools',
#   '/google/mozc-devices',
#   '/google/jsontoken',
#   '/google/microscopeimagequality',
#   '/google/google-reauth-python',
#   '/google/vogon',
#   '/google/automl-video-ondevice',
#   '/google/go-tspi',
#   '/google/go-replayers',
#   '/google/gulava',
#   '/google/android-key-attestation',
#   '/google/analytics-audience-automation-tool',
#   '/google/gxui',
#   '/google/anthos-microk8s'],
#  ['/google/python-laurel',
#   '/google/schemaorg-java',
#   '/google/nvidia_libs_test',
#   '/google/mail-importer',
#   '/google/breadboard',
#   '/google/xssxss',
#   '/google/vc-defer',
#   '/google/pix-image-viewer',
#   '/google/pre-commit-tool-hooks',
#   '/google/device-access-codelab-web-app',
#   '/google/next-prediction',
#   '/google/ml-fairness-gym',
#   '/google/mentornet',
#   '/google/firing-range',
#   '/google/libprotobuf-mutator',
#   '/google/EtwToPprof',
#   '/google/lifetime_value',
#   '/google/CTAP2-test-tool-corpus',
#   '/google/portrait-shadow-manipulation',
#   '/google/gcm',
#   '/google/codeu_project_2017',
#   '/google/google-api-java-client-samples',
#   '/google/libprio-cc',
#   '/google/favcolor-server',
#   '/google/synthmark',
#   '/google/cpu-check',
#   '/google/safebrowsing',
#   '/google/piex',
#   '/google/tuneup.dart',
#   '/google/wmt19-paraphrased-references'],
#  ['/google/llvm-propeller',
#   '/google/libnop',
#   '/google/speed-opportunity-finder',
#   '/google/go-streaming-globber',
#   '/google/cluster-data',
#   '/google/patrick',
#   '/google/mirror-branch-action',
#   '/google/kilt',
#   '/google/badwolf-drivers',
#   '/google/bazel_rules_install',
#   '/google/pyu2f',
#   '/google/makerspace-auth',
#   '/google/context-expression-nature-study',
#   '/google/modem',
#   '/google/gnostic-go-generator',
#   '/google/roman-word-bubbling',
#   '/google/android-gradle-dsl',
#   '/google/ct-hackday-schwag',
#   '/google/p4-pdpi',
#   '/google/angular-a11y-workshop',
#   '/google/angular_cli',
#   '/google/overcoming-conflicting-data',
#   '/google/binnavi',
#   '/google/python-cloud-utils',
#   '/google/etc2comp',
#   '/google/vkb',
#   '/google/cluster-scoped-cicd',
#   '/google/autol2',
#   '/google/ssl_logger',
#   '/google/rekall-profiles'],
#  ['/google/rekall',
#   '/google/woff2',
#   '/google/cloud-print-connector',
#   '/google/seq2seq',
#   '/google/inject.dart',
#   '/google/libprotobuf-mutator-asn1',
#   '/google/u2f-ref-code',
#   '/google/tinkCryptoHelper',
#   '/google/in-silico-labeling',
#   '/google/shell-encryption',
#   '/google/berrydb',
#   '/google/closure-stylesheets',
#   '/google/play-work',
#   '/google/android-arscblamer',
#   '/google/render-timing-for-unity',
#   '/google/healthcare-text-annotation',
#   '/google/EXEgesis',
#   '/google/import-mailbox-to-gmail',
#   '/google/gfbuild-angle',
#   '/google/dynamic-form',
#   '/google/transitfeed',
#   '/google/tcp_killer',
#   '/google/mimosa',
#   '/google/madi',
#   '/google/php-crc32',
#   '/google/cuckoo-index',
#   '/google/supersonic',
#   '/google/files.dart',
#   '/google/gumbo-parser',
#   '/google/minijail'],
#  ['/google/ezgantt',
#   '/google/robotstxt-java',
#   '/google/subpar',
#   '/google/meet-on-fhir',
#   '/google/auction-insights-visualization',
#   '/google/orthotope',
#   '/google/sample-sql-translator',
#   '/google/bgu',
#   '/google/actions-on-google-pq2-template-sdk',
#   '/google/scrollytell',
#   '/google/cpp-async-rpc',
#   '/google/article-recommender',
#   '/google/truestreet',
#   '/google/cm-creatives-drive-uploader',
#   '/google/opencasebook',
#   '/google/farmhash',
#   '/google/goterm',
#   '/google/spectral-density',
#   '/google/lasso',
#   '/google/soong_verification',
#   '/google/causal-panel-synthetic-data',
#   '/google/wicked-good-xpath',
#   '/google/processingjs-ide',
#   '/google/gcp-fwrule-open-domain',
#   '/google/mathfu',
#   '/google/uis-rnn',
#   '/google/b-con',
#   '/google/x-amber',
#   '/google/calblink',
#   '/google/swiftshader'],
#  ['/google/python-temescal',
#   '/google/ktsan',
#   '/google/inspectorspacetime',
#   '/google/fusion-power-video',
#   '/google/vulkan-pre-rotation-demo',
#   '/google/rescue-tools-reiserfs',
#   '/google/cloud-network-reachability',
#   '/google/zero-touch-reseller-tool',
#   '/google/controlled-noisy-web-labels',
#   '/google/walk',
#   '/google/dv360-bidbyweather',
#   '/google/self-published-geo',
#   '/google/vim-glaive',
#   '/google/iosched-ios',
#   '/google/pymql',
#   '/google/tf_mesh_renderer',
#   '/google/asset-check',
#   '/google/har2csv',
#   '/google/agency-ads-management-solutions',
#   '/google/compynator',
#   '/google/edf',
#   '/google/hrx',
#   '/google/dv-3po',
#   '/google/mlir-npcomp',
#   '/google/knowledge-base-gmail-addon',
#   '/google/peg-typed',
#   '/google/mobly-snippet-lib',
#   '/google/closure-compiler-js',
#   '/google/ui-exp-dg',
#   '/google/wwwbasic'],
#  ['/google/serde_json5',
#   '/google/py-ast-utils',
#   '/google/sonic-p4rt',
#   '/google/repose',
#   '/google/abstracttext',
#   '/google/or-models',
#   '/google/git-sync-changes',
#   '/google/airdialogue_model',
#   '/google/iot-environment-sensors',
#   '/google/airdialogue',
#   '/google/macops-MOLXPCConnection',
#   '/google/gvisor-containerd-shim',
#   '/google/guetzli',
#   '/google/lipsync',
#   '/google/haskell-trainings',
#   '/google/git-tree',
#   '/google/prochlo',
#   '/google/hover',
#   '/google/ukey2',
#   '/google/e3d_lstm',
#   '/google/python-gflags',
#   '/google/rtc-video-quality',
#   '/google/chatbase-python',
#   '/google/rerast',
#   '/google/loaner',
#   '/google/tpm-js',
#   '/google/lexical-masks',
#   '/google/nsync',
#   '/google/cloud-network-reachabilty',
#   '/google/vbootrom']]

# %%
for url in urls[39:50]:
    soup = make_soup(url)
    repos = get_repo_linksuffix()
    repo_links.append(repos)
    repo_links

# %%
len(repo_links)
# Out:
# 44

# %%
repo_links
# Out:
# [['/google/sentencepiece',
#   '/google/llvm-bazel',
#   '/google/flatbuffers',
#   '/google/trax',
#   '/google/evcxr',
#   '/google/proto-quic',
#   '/google/bulkan',
#   '/google/XNNPACK',
#   '/google/autocxx',
#   '/google/model-viewer',
#   '/google/iree',
#   '/google/ksp',
#   '/google/rust_icu',
#   '/google/BIG-bench',
#   '/google/blockly',
#   '/google/pigweed',
#   '/google/filament',
#   '/google/blockly-samples',
#   '/google/web-stories-wp',
#   '/google/gvisor',
#   '/google/cssi-labs',
#   '/google/jax',
#   '/google/gfbuild-glslang',
#   '/google/nomulus',
#   '/google/pytype',
#   '/google/glog',
#   '/google/zx',
#   '/google/martian',
#   '/google/exposure-notifications-private-analytics-ingestion',
#   '/google/GoogleUtilities'],
#  ['/google/ecclesia-machine-management',
#   '/google/ground-platform',
#   '/google/CFU-Playground',
#   '/google/shaka-player',
#   '/google/turbinia',
#   '/google/gtm-session-fetcher',
#   '/google/ffn',
#   '/google/earthenterprise',
#   '/google/it-cert-automation-practice',
#   '/google/gin-config',
#   '/google/vscode-bigquery',
#   '/google/docsy-example',
#   '/google/privacy-sandbox-aggregation-service',
#   '/google/fonts',
#   '/google/clasp',
#   '/google/nearby-connections',
#   '/google/cadvisor',
#   '/google/create-service-account',
#   '/google/oss-fuzz',
#   '/google/dopamine',
#   '/google/closure-compiler-npm',
#   '/google/elements-sk',
#   '/google/fhir',
#   '/google/CommonLoopUtils',
#   '/google/dagger',
#   '/google/go-attestation',
#   '/google/uncertainty-baselines',
#   '/google/j2cl',
#   '/google/tf-quant-finance',
#   '/google/closure-compiler'],
#  ['/google/exposure-notifications-verification-server',
#   '/google/angular-directed-graph',
#   '/google/glazier',
#   '/google/perfetto',
#   '/google/error-prone',
#   '/google/j2objc',
#   '/google/xls',
#   '/google/edward2',
#   '/google/xctestrunner',
#   '/google/syzkaller',
#   '/google/site-kit-wp',
#   '/google/highway',
#   '/google/clusterfuzz',
#   '/google/closure-library',
#   '/google/clif',
#   '/google/orbit',
#   '/google/shaka-packager',
#   '/google/ml-metadata',
#   '/google/exposure-notifications-server',
#   '/google/github-owners-bot',
#   '/google/kotlin',
#   '/google/tink',
#   '/google/zazu',
#   '/google/stijl',
#   '/google/knative-gcp',
#   '/google/googet',
#   '/google/accompanist',
#   '/google/logger',
#   '/google/safevalues',
#   '/google/flogger'],
#  ['/google/gps_building_blocks',
#   '/google/boringssl',
#   '/google/clspv',
#   '/google/season-of-docs',
#   '/google/graphicsfuzz',
#   '/google/copybara',
#   '/google/homebrew-verible',
#   '/google/agi-dev-releases',
#   '/google/flax',
#   '/google/nsjail',
#   '/google/peoplemath',
#   '/google/kafel',
#   '/google/pprof-nodejs',
#   '/google/megalista',
#   '/google/timesketch',
#   '/google/starlark-go',
#   '/google/rrg',
#   '/google/conscrypt',
#   '/google/accname',
#   '/google/semantic-locators',
#   '/google/agi',
#   '/google/truth',
#   '/google/ExoPlayer',
#   '/google/typedoc-neo-theme',
#   '/google/go-github',
#   '/google/benchmark',
#   '/google/mdl-ref-apps',
#   '/google/binexport',
#   '/google/service-worker-detector',
#   '/google/wikiloop-doublecheck'],
#  ['/google/data-layer-helper',
#   '/google/oss-fuzz-vulns',
#   '/google/node-fastify-auto-push',
#   '/google/dv360-api',
#   '/google/pack-n-play',
#   '/google/startup-os',
#   '/google/ground-android',
#   '/google/transmat',
#   '/google/android-fhir',
#   '/google/dart_cli_pkg',
#   '/google/nodejs-container-image-builder',
#   '/google/llvm-premerge-checks',
#   '/google/voice-builder',
#   '/google/myanmar-tools',
#   '/google/oatts',
#   '/google/docsy',
#   '/google/go-jsonnet',
#   '/google/libphonenumber',
#   '/google/modernstorage',
#   '/google/shadertrap',
#   '/google/cloud-forensics-utils',
#   '/google/mtail',
#   '/google/cabbie',
#   '/google/go-cloud',
#   '/google/personfinder',
#   '/google/fuzzing',
#   '/google/osv',
#   '/google/eng-edu',
#   '/google/postcss-rename',
#   '/google/python-fire'],
#  ['/google/grr',
#   '/google/dart_cli_script',
#   '/google/qkeras',
#   '/google/ko',
#   '/google/starthinker',
#   '/google/tsec',
#   '/google/proto-lens',
#   '/google/gazoo-device',
#   '/google/or-tools',
#   '/google/kne',
#   '/google/incremental-dom',
#   '/google/fleetspeak',
#   '/google/pprof',
#   '/google/guava',
#   '/google/oauth2l',
#   '/google/data-transfer-project',
#   '/google/breakpad',
#   '/google/s2a-core',
#   '/google/deluca',
#   '/google/triage-party',
#   '/google/learn-oss-with-google',
#   '/google/go-tpm-tools',
#   '/google/auto',
#   '/google/crmint',
#   '/google/playhvz',
#   '/google/skywater-pdk-actions',
#   '/google/fedjax',
#   '/google/slo-generator',
#   '/google/inverting-proxy',
#   '/google/verible'],
#  ['/google/ruy',
#   '/google/draco',
#   '/google/earthengine-api',
#   '/google/tarpc',
#   '/google/iree-llvm-sandbox',
#   '/google/skia-buildbot',
#   '/google/capirca',
#   '/google/go-safeweb',
#   '/google/driblet',
#   '/google/transit',
#   '/google/sandboxed-api',
#   '/google/trillian-examples',
#   '/google/devlibrary',
#   '/google/mobly',
#   '/google/s2geometry',
#   '/google/built_value.dart',
#   '/google/go-containerregistry',
#   '/google/js-green-licenses',
#   '/google/WebFundamentals',
#   '/google/CodeCity',
#   '/google/reflectable.dart',
#   '/google/bamboo-soy',
#   '/google/cloudprober',
#   '/google/talkback',
#   '/google/neuroglancer',
#   '/google/fscrypt',
#   '/google/swiftlogfirecloud',
#   '/google/brotli',
#   '/google/ac-library.cr',
#   '/google/eleventy-high-performance-blog'],
#  ['/google/go-flow-levee',
#   '/google/apitools',
#   '/google/git-presubmit-linter',
#   '/google/earthengine-community',
#   '/google/flutter.widgets',
#   '/google/chartjs.dart',
#   '/google/ehr-predictions',
#   '/google/eventid-js',
#   '/google/argh',
#   '/google/tock-on-titan',
#   '/google/seqio',
#   '/google/skywater-pdk-libs-sky130_fd_sc_hd',
#   '/google/mediapipe',
#   '/google/wmt-mqm-human-evaluation',
#   '/google/bulkdozer-lite',
#   '/google/project-OCEAN',
#   '/google/gts',
#   '/google/lldb-eval',
#   '/google/souper',
#   '/google/fuzzbench',
#   '/google/digitalbuildings',
#   '/google/googletest',
#   '/google/open-location-code',
#   '/google/snappy',
#   '/google/k8s-digester',
#   '/google/GTMAppAuth',
#   '/google/GoogleAppMeasurement',
#   '/google/gofuzz',
#   '/google/blockly-games',
#   '/google/Kotlin-FirViewer'],
#  ['/google/polymorphicDSL',
#   '/google/yapf',
#   '/google/go-cmp',
#   '/google/tcmalloc',
#   '/google/certtostore',
#   '/google/google-java-format',
#   '/google/cvelist',
#   '/google/command-fds',
#   '/google/glome',
#   '/google/marzipano',
#   '/google/guice',
#   '/google/wuffs',
#   '/google/promises',
#   '/google/butteraugli',
#   '/google/dart-neats',
#   '/google/mug',
#   '/google/re2',
#   '/google/santa',
#   '/google/android-uiconductor',
#   '/google/bloaty',
#   '/google/renameio',
#   '/google/play-services-plugins',
#   '/google/closure-templates',
#   '/google/macops-MOLAuthenticatingURLSession',
#   '/google/differential-privacy',
#   '/google/civics_cdf_validator',
#   '/google/CTAP2-test-tool',
#   '/google/hashtable-benchmarks',
#   '/google/speaker-id',
#   '/google/trillian'],
#  ['/google/pyvisionproductsearch',
#   '/google/certificate-transparency-go',
#   '/google/AFL',
#   '/google/osqp-cpp',
#   '/google/moveit',
#   '/google/gnostic',
#   '/google/flutter-desktop-embedding',
#   '/google/leveldb',
#   '/google/fledge-shim',
#   '/google/trimmed_match',
#   '/google/ghc-source-gen',
#   '/google/ml-compiler-opt',
#   '/google/omaha',
#   '/google/oculi',
#   '/google/mono_repo.dart',
#   '/google/making_with_ml',
#   '/google/dqm',
#   '/google/patents-public-data',
#   '/google/coding-with-chrome',
#   '/google/certificate-transparency-rfcs',
#   '/google/der-ascii',
#   '/google/libtrusttoken',
#   '/google/oboe',
#   '/google/tsunami-security-scanner-plugins',
#   '/google/skia',
#   '/google/bms-toolkit',
#   '/google/gopacket',
#   '/google/xtoproto',
#   '/google/triggerator',
#   '/google/virtual-authenticators-tab'],
#  ['/google/material-design-icons',
#   '/google/nixery',
#   '/google/argon',
#   '/google/alligator2',
#   '/google/schedviz',
#   '/google/desugar_jdk_libs',
#   '/google/goexpect',
#   '/google/common-sk',
#   '/google/eDistantObject',
#   '/google/EarlGrey',
#   '/google/skywater-pdk-libs-sky130_bag3_pr',
#   '/google/go-licenses',
#   '/google/skywater-pdk',
#   '/google/process_runner',
#   '/google/keytransparency',
#   '/google/jsonnet',
#   '/google/distributed_point_functions',
#   '/google/chive-prosody',
#   '/google/eidos-audition',
#   '/google/riegeli',
#   '/google/grr-doc',
#   '/google/jax-md',
#   '/google/google-ctf',
#   '/google/mweb-analysis-tools',
#   '/google/private-join-and-compute',
#   '/google/json5format',
#   '/google/bundletool',
#   '/google/blueprint',
#   '/google/gfbuild-amber',
#   '/google/gfbuild-llpc'],
#  ['/google/compile-testing',
#   '/google/eng-practices',
#   '/google/addlicense',
#   '/google/go-dap',
#   '/google/secrets-sync-action',
#   '/google/j2cl-protobuf',
#   '/google/errorprone-rest-plugin',
#   '/google/autofdo',
#   '/google/json_serializable.dart',
#   '/google/amber',
#   '/google/brotli-wheels',
#   '/google/pkcs11test',
#   '/google/UIforETW',
#   '/google/mysql-ripple',
#   '/google/vim-maktaba',
#   '/google/sanitizers',
#   '/google/cel-go',
#   '/google/riscv-dv',
#   '/google/DAPLink-port',
#   '/google/df-conformer',
#   '/google/lyra',
#   '/google/atheris',
#   '/google/gousb',
#   '/google/TaglessCRM',
#   '/google/zoekt',
#   '/google/android-emulator-container-scripts',
#   '/google/vim-coverage',
#   '/google/eme-encryption-scheme-polyfill',
#   '/google/android-lint-performance-probe',
#   '/google/visqol'],
#  ['/google/ide-perf',
#   '/google/apt-golang-s3',
#   '/google/TestParameterInjector',
#   '/google/OpenSK',
#   '/google/styleguide',
#   '/google/google-id-token',
#   '/google/ts-bridge',
#   '/google/extra-keyboards-for-chrome-os',
#   '/google/flutter.plugins',
#   '/google/gson',
#   '/google/googleapis.dart',
#   '/google/webdriver.dart',
#   '/google/mozc',
#   '/google/marl',
#   '/google/honggfuzz',
#   '/google/openhtf',
#   '/google/password-alert',
#   '/google/automl',
#   '/google/mechahamster',
#   '/google/gmail-oauth2-tools',
#   '/google/cargo-raze',
#   '/google/skywater-pdk-libs-sky130_fd_io',
#   '/google/skywater-pdk-libs-sky130_fd_pr',
#   '/google/skywater-pdk-libs-sky130_fd_sc_hdll',
#   '/google/skywater-pdk-libs-sky130_fd_sc_hs',
#   '/google/skywater-pdk-libs-sky130_fd_sc_hvl',
#   '/google/skywater-pdk-libs-sky130_fd_sc_ls',
#   '/google/skywater-pdk-libs-sky130_fd_sc_ms',
#   '/google/skywater-pdk-libs-sky130_fd_sc_lp',
#   '/google/report2bq'],
#  ['/google/secrets-gradle-plugin',
#   '/google/cbortree',
#   '/google/coapblaster',
#   '/google/struct2tensor',
#   '/google/strict-csp',
#   '/google/dv360-api-appsscript-samples',
#   '/google/gnxi',
#   '/google/git-appraise',
#   '/google/rdma-unit-test',
#   '/google/protobuf-gradle-plugin',
#   '/google/libaddressinput',
#   '/google/zetasql',
#   '/google/copr-sundry',
#   '/google/duet',
#   '/google/tacotron',
#   '/google/ga4-gtm-migration',
#   '/google/packetdrill',
#   '/google/shaderc',
#   '/google/live-transcribe-speech-engine',
#   '/google/play-unity-plugins',
#   '/google/shoptimizer',
#   '/google/coset',
#   '/google/highwayhash',
#   '/google/tsunami-security-scanner',
#   '/google/wire',
#   '/google/objax',
#   '/google/pullsheet',
#   '/google/perf_data_converter',
#   '/google/neural-tangents',
#   '/google/meterstick'],
#  ['/google/vulncode-db',
#   '/google/formal-ml',
#   '/google/badwolf',
#   '/google/cyanobyte',
#   '/google/kunit-docs',
#   '/google/codemirror.dart',
#   '/google/GoogleDataTransport',
#   '/google/github-release-retry',
#   '/google/cel-spec',
#   '/google/cpp-from-the-sky-down',
#   '/google/basis_universal',
#   '/google/winops',
#   '/google/aidl-language',
#   '/google/selinux-policy-languages',
#   '/google/sketch2ae',
#   '/google/grinder.dart',
#   '/google/google-api-objectivec-client-for-rest',
#   '/google/kctf',
#   '/google/shopping-markup',
#   '/google/assetMG',
#   '/google/pub_cache',
#   '/google/resultstoreui',
#   '/google/link-diver',
#   '/google/android-cuttlefish',
#   '/google/nginx-sxg-module',
#   '/google/webpackager',
#   '/google/mysteryofthreebots',
#   '/google/tweakr',
#   '/google/licensecheck',
#   '/google/semantic-release-replace-plugin'],
#  ['/google/spatial-media',
#   '/google/sagetv',
#   '/google/vector_math.dart',
#   '/google/picatrix',
#   '/google/codeworld',
#   '/google/charts',
#   '/google/vim-colorscheme-primary',
#   '/google/vimdoc',
#   '/google/alertmanager-irc-relay',
#   '/google/TensorNetwork',
#   '/google/gops',
#   '/google/jarjar',
#   '/google/cabal2bazel',
#   '/google/deepvariant',
#   '/google/ads-privacy',
#   '/google/.github',
#   '/google/fractribution',
#   '/google/vim-codefmt',
#   '/google/reflow-list',
#   '/google/aiyprojects-raspbian',
#   '/google/ffcc',
#   '/google/aiyprojects-raspbian-tools',
#   '/google/go-tpm',
#   '/google/android-emulator-webrtc',
#   '/google/asylo',
#   '/google/recaptcha',
#   '/google/go-querystring',
#   '/google/trillian-website',
#   '/google/bi-tempered-loss',
#   '/google/cppdap'],
#  ['/google/retriever_parsing',
#   '/google/custom-tab-groups',
#   '/google/intellij-gn-plugin',
#   '/google/kasan',
#   '/google/prog-edu-assistant-quizzes',
#   '/google/cpu_features',
#   '/google/localized-narratives',
#   '/google/usbinfo',
#   '/google/shaka-streamer',
#   '/google/turbine',
#   '/google/jimfs',
#   '/google/chrometracing',
#   '/google/generic-webdriver-server',
#   '/google/gfbuild-swiftshader',
#   '/google/java-monitoring-client-library',
#   '/google/autocjk',
#   '/google/cld3',
#   '/google/sa360-webquery-bigquery',
#   '/google/quiver-dart',
#   '/google/jsonapi',
#   '/google/double-conversion',
#   '/google/ngx_brotli',
#   '/google/rpmpack',
#   '/google/taqo-paco',
#   '/google/devx-tools',
#   '/google/pygtrie',
#   '/google/kmsan',
#   '/google/gf-layers',
#   '/google/fruit',
#   '/google/jsaction'],
#  ['/google/lecam-gan',
#   '/google/GCP-deployment-scripts-for-PI-Core',
#   '/google/pcbdl',
#   '/google/standard-payments',
#   '/google/TrustScore',
#   '/google/instrumentsToPprof',
#   '/google/capsicum-test',
#   '/google/security-research',
#   '/google/outrigger',
#   '/google/certificate-transparency-community-site',
#   '/google/slowjam',
#   '/google/tabletopaudio-action',
#   '/google/volley',
#   '/google/brunsli',
#   '/google/connectedappssdk',
#   '/google/uuid',
#   '/google/matched_markets',
#   '/google/dfdewey',
#   '/google/look-before-you-speak',
#   '/google/google-api-javascript-client',
#   '/google/scaaml',
#   '/google/caliper',
#   '/google/escapevelocity',
#   '/google/inject-common',
#   '/google/guava-beta-checker',
#   '/google/web-serial-polyfill',
#   '/google/gsocguides',
#   '/google/wuffs-mirror-release-c',
#   '/google/stenographer',
#   '/google/google-drive-dokany'],
#  ['/google/applied-machine-learning-intensive',
#   '/google/nucleus',
#   '/google/google-toolbox-for-mac',
#   '/google/tirg',
#   '/google/webauthndemo',
#   '/google/source_helper.dart',
#   '/google/codesearch',
#   '/google/libsxg',
#   '/google/autobidding-readiness-monitor',
#   '/google/deepmac',
#   '/google/centaur',
#   '/google/mediapy',
#   '/google/platform.dart',
#   '/google/multichase',
#   '/google/git-appraise-web',
#   '/google/gfbuild-graphicsfuzz',
#   '/google/GTXiLib',
#   '/google/react-schemaorg',
#   '/google/licenseclassifier',
#   '/google/merror',
#   '/google/santa-tracker-web',
#   '/google/framework-for-osdu',
#   '/google/schema-dts',
#   '/google/actions-on-google-flashcards-template-sdk',
#   '/google/actions-on-google-trivia-template-sdk',
#   '/google/rejoiner',
#   '/google/jse4conf',
#   '/google/splot-java',
#   '/google/MOE',
#   '/google/cel-cpp'],
#  ['/google/allocation-instrumenter',
#   '/google/hotel-booking-api-validator',
#   '/google/wikiloop-explorer',
#   '/google/tamperchrome',
#   '/google/sqlcommenter',
#   '/google/web-starter-kit',
#   '/google/iconvg',
#   '/google/node-gles',
#   '/google/googlesource-auth-tools',
#   '/google/cctz',
#   '/google/chicago-brick',
#   '/google/ngrx-visualizer',
#   '/google/starlark-rust',
#   '/google/emoji-scavenger-hunt',
#   '/google/nanopb-podspec',
#   '/google/pawn',
#   '/google/vxsig',
#   '/google/vim-ft-go',
#   '/google/protodatastore-cpp',
#   '/google/python-spanner-orm',
#   '/google/web-api-gateway',
#   '/google/ml_collections',
#   '/google/code-review-bot',
#   '/google/model_search',
#   '/google/upvote',
#   '/google/huproxy',
#   '/google/bband-adaband',
#   '/google/re2j',
#   '/google/vim-jsonnet',
#   '/google/cm360-audience-manager'],
#  ['/google/memcpy-gemm',
#   '/google/process.dart',
#   '/google/brain-tokyo-workshop',
#   '/google/exposure-notifications-android',
#   '/google/csp-evaluator',
#   '/google/go-pcie-tlp',
#   '/google/dspl',
#   '/google/observable',
#   '/google/pinject',
#   '/google/wasserstein-dist',
#   '/google/har-sanitizer',
#   '/google/dotty',
#   '/google/gtest-parallel',
#   '/google/dart-basics',
#   '/google/go-intervals',
#   '/google/exposure-notifications-internals',
#   '/google/CausalImpact',
#   '/google/go-pcie-screamer',
#   '/google/sge-monorepo',
#   '/google/nsscache',
#   '/google/sa360-bigquery-bootstrapper',
#   '/google/monster-mash',
#   '/google/plusfish',
#   '/google/pasta',
#   '/google/ldif',
#   '/google/gov-meetings-made-searchable',
#   '/google/opendocs',
#   '/google/prefab',
#   '/google/material-design-lite',
#   '/google/bazel-common'],
#  ['/google/xsecurelock',
#   '/google/dart-json_diff',
#   '/google/archive-patcher',
#   '/google/paragraph',
#   '/google/http_pattern_matcher',
#   '/google/vulkan_test_applications',
#   '/google/ansicolor-dart',
#   '/google/youtube-8m',
#   '/google/brailleback',
#   '/google/flexbox-layout',
#   '/google/ctfscoreboard',
#   '/google/btree',
#   '/google/myelin-acorn-electron-hardware',
#   '/google/hubvantage',
#   '/google/webcrypto.dart',
#   '/google/shaderc-rs',
#   '/google/adb-sync',
#   '/google/uVkCompute',
#   '/google/fusion-tables-drive-export',
#   '/google/gfbuild-shadertrap',
#   '/google/example_extrapolation',
#   '/google/security-research-pocs',
#   '/google/tuple.dart',
#   '/google/gfbuild-SPIRV-Tools',
#   '/google/cel-policy-templates-go',
#   '/google/safehtml',
#   '/google/gnostic-grpc',
#   '/google/oss-vulnerability-guide',
#   '/google/ga360-bqml-toolkit',
#   '/google/corpuscrawler'],
#  ['/google/cocoapods-size',
#   '/google/bongo',
#   '/google/software-product-sprint',
#   '/google/pytruth',
#   '/google/android-emulator-m1-preview',
#   '/google/mathsteps',
#   '/google/nitroml',
#   '/google/fusion-tables-archive-visualizer',
#   '/google/poseshield-tfjs',
#   '/google/fhir-examples',
#   '/google/ms-tpm-20-ref',
#   '/google/aistplusplus_dataset',
#   '/google/x509test',
#   '/google/neural-light-transport',
#   '/google/digitalassetlinks',
#   '/google/svcca',
#   '/google/jwt_verify_lib',
#   '/google/uri.dart',
#   '/google/diff-match-patch',
#   '/google/google-my-business-samples',
#   '/google/aistplusplus_api',
#   '/google/perforce-utils',
#   '/google/file-based-test-driver',
#   '/google/pedantic',
#   '/google/eslint-config-google',
#   '/google/flight-lab',
#   '/google/carfac',
#   '/google/robotstxt',
#   '/google/language-jsonnet',
#   '/google/paseos'],
#  ['/google/vk_callback_swapchain',
#   '/google/GiftStick',
#   '/google/santa-tracker-android',
#   '/google/binja-hexagon',
#   '/google/webkit_inspection_protocol.dart',
#   '/google/jsinterop-annotations',
#   '/google/jsinterop-base',
#   '/google/jsinterop-generator',
#   '/google/elemental2',
#   '/google/gps-measurement-tools',
#   '/google/ion',
#   '/google/platform_benchmarks',
#   '/google/simhospital',
#   '/google/arrow-logo',
#   '/google/stm32_bare_lib',
#   '/google/new-project',
#   '/google/aukera',
#   '/google/empirical_calibration',
#   '/google/kati',
#   '/google/node-h2-auto-push',
#   '/google/webrisk',
#   '/google/usbmon',
#   '/google/timecast',
#   '/google/quic-trace',
#   '/google/google-authenticator-libpam',
#   '/google/vimscript-language-server',
#   '/google/vroom',
#   '/google/smbios-validation-tool',
#   '/google/fleetspeak-rs',
#   '/google/schemarama'],
#  ['/google/redgrep',
#   '/google/mobly-bundled-snippets',
#   '/google/ormolu',
#   '/google/file.dart',
#   '/google/hdrnet',
#   '/google/asylo-site',
#   '/google/asylo-examples',
#   '/google/tcav-for-ehr',
#   '/google/neper',
#   '/google/dicomproxy',
#   '/google/idaidle',
#   '/google/play-licensing',
#   '/google/feedloader',
#   '/google/quiver-log',
#   '/google/forklift',
#   '/google/deepdream',
#   '/google/webbundle',
#   '/google/iosched',
#   '/google/prog-edu-assistant',
#   '/google/GSCXScanner',
#   '/google/acai',
#   '/google/java-photoslibrary',
#   '/google/ftc-object-detection',
#   '/google/macops',
#   '/google/re2-wasm',
#   '/google/language-resources',
#   '/google/tsunami',
#   '/google/cronutils',
#   '/google/crc32c',
#   '/google/fscryptctl'],
#  ['/google/splice',
#   '/google/securemessage',
#   '/google/caliban',
#   '/google/pageloader',
#   '/google/lkml-gerrit-bridge',
#   '/google/zuckerli',
#   '/google/dv360-automation',
#   '/google/spindle-dv360',
#   '/google/canvas-5-polyfill',
#   '/google/vpn-libraries',
#   '/google/trueview-sdf-generator',
#   '/google/lisp-koans',
#   '/google/mannequinchallenge',
#   '/google/html-quiz',
#   '/google/lintush',
#   '/google/skicka',
#   '/google/ios-webkit-debug-proxy',
#   '/google/cauliflowervest',
#   '/google/importlab',
#   '/google/cdep',
#   '/google/emboss',
#   '/google/gemmlowp',
#   '/google/unsmear',
#   '/google/vsaq',
#   '/google/spirv-tutor',
#   '/google/StrawNet',
#   '/google/periph',
#   '/google/retiming',
#   '/google/google.github.io',
#   '/google/aistreams'],
#  ['/google/ci_edit',
#   '/google/hotels-template-library',
#   '/google/safeside',
#   '/google/ads-account-structure-script',
#   '/google/blockly-ios',
#   '/google/makani',
#   '/google/android-emulator-hypervisor-driver-for-amd-processors',
#   '/google/swift-jupyter',
#   '/google/open-gantry',
#   '/google/python-adb',
#   '/google/pybadges',
#   '/google/note-maps',
#   '/google/nftables',
#   '/google/swift',
#   '/google/kf',
#   '/google/php-photoslibrary',
#   '/google/coursebuilder-core',
#   '/google/tangent',
#   '/google/gitiles',
#   '/google/hypebot',
#   '/google/intermock',
#   '/google/python_portpicker',
#   '/google/lovefield',
#   '/google/python-lakeside',
#   '/google/path-auditor',
#   '/google/device-access-sample-web-app',
#   '/google/xscreensaver-dbus',
#   '/google/go-cmdtest',
#   '/google/tim-gan',
#   '/google/blockbuster'],
#  ['/google/tensorflow-recorder',
#   '/google/android-classyshark',
#   '/google/coding-with-chrome-libraries',
#   '/google/dnsmasq_exporter',
#   '/google/go-tika',
#   '/google/shaka-player-embedded',
#   '/google/crfs',
#   '/google/swift-structural',
#   '/google/spherical-harmonics',
#   '/google/latexify_py',
#   '/google/tcli',
#   '/google/hammer-kit',
#   '/google/openrtb',
#   '/google/spatiotemporal-graphnn-tf',
#   '/google/reftable',
#   '/google/usd_from_gltf',
#   '/google/ubntools',
#   '/google/mozc-devices',
#   '/google/jsontoken',
#   '/google/microscopeimagequality',
#   '/google/google-reauth-python',
#   '/google/vogon',
#   '/google/automl-video-ondevice',
#   '/google/go-tspi',
#   '/google/go-replayers',
#   '/google/gulava',
#   '/google/android-key-attestation',
#   '/google/analytics-audience-automation-tool',
#   '/google/gxui',
#   '/google/anthos-microk8s'],
#  ['/google/python-laurel',
#   '/google/schemaorg-java',
#   '/google/nvidia_libs_test',
#   '/google/mail-importer',
#   '/google/breadboard',
#   '/google/xssxss',
#   '/google/vc-defer',
#   '/google/pix-image-viewer',
#   '/google/pre-commit-tool-hooks',
#   '/google/device-access-codelab-web-app',
#   '/google/next-prediction',
#   '/google/ml-fairness-gym',
#   '/google/mentornet',
#   '/google/firing-range',
#   '/google/libprotobuf-mutator',
#   '/google/EtwToPprof',
#   '/google/lifetime_value',
#   '/google/CTAP2-test-tool-corpus',
#   '/google/portrait-shadow-manipulation',
#   '/google/gcm',
#   '/google/codeu_project_2017',
#   '/google/google-api-java-client-samples',
#   '/google/libprio-cc',
#   '/google/favcolor-server',
#   '/google/synthmark',
#   '/google/cpu-check',
#   '/google/safebrowsing',
#   '/google/piex',
#   '/google/tuneup.dart',
#   '/google/wmt19-paraphrased-references'],
#  ['/google/llvm-propeller',
#   '/google/libnop',
#   '/google/speed-opportunity-finder',
#   '/google/go-streaming-globber',
#   '/google/cluster-data',
#   '/google/patrick',
#   '/google/mirror-branch-action',
#   '/google/kilt',
#   '/google/badwolf-drivers',
#   '/google/bazel_rules_install',
#   '/google/pyu2f',
#   '/google/makerspace-auth',
#   '/google/context-expression-nature-study',
#   '/google/modem',
#   '/google/gnostic-go-generator',
#   '/google/roman-word-bubbling',
#   '/google/android-gradle-dsl',
#   '/google/ct-hackday-schwag',
#   '/google/p4-pdpi',
#   '/google/angular-a11y-workshop',
#   '/google/angular_cli',
#   '/google/overcoming-conflicting-data',
#   '/google/binnavi',
#   '/google/python-cloud-utils',
#   '/google/etc2comp',
#   '/google/vkb',
#   '/google/cluster-scoped-cicd',
#   '/google/autol2',
#   '/google/ssl_logger',
#   '/google/rekall-profiles'],
#  ['/google/rekall',
#   '/google/woff2',
#   '/google/cloud-print-connector',
#   '/google/seq2seq',
#   '/google/inject.dart',
#   '/google/libprotobuf-mutator-asn1',
#   '/google/u2f-ref-code',
#   '/google/tinkCryptoHelper',
#   '/google/in-silico-labeling',
#   '/google/shell-encryption',
#   '/google/berrydb',
#   '/google/closure-stylesheets',
#   '/google/play-work',
#   '/google/android-arscblamer',
#   '/google/render-timing-for-unity',
#   '/google/healthcare-text-annotation',
#   '/google/EXEgesis',
#   '/google/import-mailbox-to-gmail',
#   '/google/gfbuild-angle',
#   '/google/dynamic-form',
#   '/google/transitfeed',
#   '/google/tcp_killer',
#   '/google/mimosa',
#   '/google/madi',
#   '/google/php-crc32',
#   '/google/cuckoo-index',
#   '/google/supersonic',
#   '/google/files.dart',
#   '/google/gumbo-parser',
#   '/google/minijail'],
#  ['/google/python-temescal',
#   '/google/ktsan',
#   '/google/inspectorspacetime',
#   '/google/fusion-power-video',
#   '/google/vulkan-pre-rotation-demo',
#   '/google/rescue-tools-reiserfs',
#   '/google/cloud-network-reachability',
#   '/google/zero-touch-reseller-tool',
#   '/google/controlled-noisy-web-labels',
#   '/google/walk',
#   '/google/dv360-bidbyweather',
#   '/google/self-published-geo',
#   '/google/vim-glaive',
#   '/google/iosched-ios',
#   '/google/pymql',
#   '/google/tf_mesh_renderer',
#   '/google/asset-check',
#   '/google/har2csv',
#   '/google/agency-ads-management-solutions',
#   '/google/compynator',
#   '/google/edf',
#   '/google/hrx',
#   '/google/dv-3po',
#   '/google/mlir-npcomp',
#   '/google/knowledge-base-gmail-addon',
#   '/google/peg-typed',
#   '/google/mobly-snippet-lib',
#   '/google/closure-compiler-js',
#   '/google/ui-exp-dg',
#   '/google/wwwbasic'],
#  ['/google/serde_json5',
#   '/google/py-ast-utils',
#   '/google/sonic-p4rt',
#   '/google/repose',
#   '/google/abstracttext',
#   '/google/or-models',
#   '/google/git-sync-changes',
#   '/google/airdialogue_model',
#   '/google/iot-environment-sensors',
#   '/google/airdialogue',
#   '/google/macops-MOLXPCConnection',
#   '/google/gvisor-containerd-shim',
#   '/google/guetzli',
#   '/google/lipsync',
#   '/google/haskell-trainings',
#   '/google/git-tree',
#   '/google/prochlo',
#   '/google/hover',
#   '/google/ukey2',
#   '/google/e3d_lstm',
#   '/google/python-gflags',
#   '/google/rtc-video-quality',
#   '/google/chatbase-python',
#   '/google/rerast',
#   '/google/loaner',
#   '/google/tpm-js',
#   '/google/lexical-masks',
#   '/google/nsync',
#   '/google/cloud-network-reachabilty',
#   '/google/vbootrom'],
#  ['/google/s2-geometry-library-java',
#   '/google/powered-caster-vehicle',
#   '/google/play-instant-unity-plugin',
#   '/google/mundane',
#   '/google/ukip',
#   '/google/grumpy',
#   '/google/hrepl',
#   '/google/git-appraise-eclipse',
#   '/google/fuzzer-test-suite',
#   '/google/python-fanotify',
#   '/google/slothfs',
#   '/google/emoticon-composer-font',
#   '/google/cloud-analytics-ts',
#   '/google/angular_node_bind.dart',
#   '/google/monologue',
#   '/google/allied-oscillators',
#   '/google/create-framework',
#   '/google/cortex-demos',
#   '/google/wayback-machine-button',
#   '/google/certificate-maker',
#   '/google/night-sight',
#   '/google/galogen',
#   '/google/chatbase-node',
#   '/google/active-learning',
#   '/google/guava-js-umd',
#   '/google/NeuroNER-CSPMC',
#   '/google/wycheproof',
#   '/google/fswalker',
#   '/google/cxx-std-draft',
#   '/google/gfw-deployments'],
#  ['/google/revisiting-self-supervised',
#   '/google/DOM-Tutorials',
#   '/google/jacs',
#   '/google/infra-structured-map',
#   '/google/xsecurelock-saver-rs',
#   '/google/cameraview',
#   '/google/hprof-parser',
#   '/google/gulp-google-closure-deps',
#   '/google/gerrit-linter',
#   '/google/sprockets',
#   '/google/restor',
#   '/google/blockly-experimental',
#   '/google/OctoPrint-LEDStripControl',
#   '/google/weasel',
#   '/google/OctoPrint-TemperatureFailsafe',
#   '/google/OctoPrint-HeaterTimeout',
#   '/google/mawfs',
#   '/google/segment',
#   '/google/subcommands',
#   '/google/palette.js',
#   '/google/budou',
#   '/google/certificate-transparency-java',
#   '/google/zetasketch',
#   '/google/AppSpeedIndex',
#   '/google/ijaas',
#   '/google/go-pbmoney',
#   '/google/REAPER',
#   '/google/kir-holiday-lights',
#   '/google/gpu-runtime',
#   '/google/gcnn-survey-paper'],
#  ['/google/opensmartbutton',
#   '/google/apps_script_tools',
#   '/google/macops-keychainminder',
#   '/google/embedding-tests',
#   '/google/data-driven-discretization-1d',
#   '/google/tracing-framework',
#   '/google/netstack',
#   '/google/multi-task-architecture-search',
#   '/google/pyringe',
#   '/google/eddystone',
#   '/google/statechart',
#   '/google/deputy-api-python-client',
#   '/google/synthesizer-io',
#   '/google/checkers',
#   '/google/disable-keyboard-shortcuts',
#   '/google/shlex',
#   '/google/nixysa',
#   '/google/szl',
#   '/google/abpackage',
#   '/google/gps_data_solutions',
#   '/google/sredocs',
#   '/google/tiff',
#   '/google/google-api-ruby-client-samples',
#   '/google/gpu-mux',
#   '/google/jarvan',
#   '/google/enjarify',
#   '/google/orderedcode',
#   '/google/wikiloop-wikidata-game',
#   '/google/automation-inspector',
#   '/google/floog'],
#  ['/google/icing-search',
#   '/google/distributed-git-forks',
#   '/google/phase-prediction',
#   '/google/campaign-manager-bulk-uploader',
#   '/google/swift-lldb',
#   '/google/swift-clang',
#   '/google/swift-llvm',
#   '/google/swift-corelibs-libdispatch',
#   '/google/swift-corelibs-foundation',
#   '/google/libcppbor',
#   '/google/mr4c',
#   '/google/graph-gen',
#   '/google/sa360-bidbyweather',
#   '/google/swift-corelibs-xctest',
#   '/google/payjs',
#   '/google/gfbuild-SPIRV-Cross',
#   '/google/MOE-py',
#   '/google/FluidNet',
#   '/google/brandometer',
#   '/google/AndroidForegroundCompat',
#   '/google/cloud-function-edit-drive-permissions',
#   '/google/GeoexperimentsResearch',
#   '/google/image-compression',
#   '/google/gdata-python-client',
#   '/google/flutter-provide',
#   '/google/pixelvisualcorecamera',
#   '/google/vim-searchindex',
#   '/google/retrieval-qa-eval',
#   '/google/cap-library',
#   '/google/transperf'],
#  ['/google/pulito',
#   '/google/neural_rerendering_in_the_wild',
#   '/google/TextNormalizationCoveringGrammars',
#   '/google/rxcppuniq',
#   '/google/flutter_minimal_store',
#   '/google/charted',
#   '/google/boundedwait',
#   '/google/minetest_pnr',
#   '/google/fleetspeak-doc',
#   '/google/earthstudio-ffmpeg-automator',
#   '/google/page-timer',
#   '/google/dpy',
#   '/google/crunchy',
#   '/google/google-drive-shell-extension',
#   '/google/dimsum',
#   '/google/rappor',
#   '/google/copper',
#   '/google/namebench',
#   '/google/cpix_cc',
#   '/google/intellij-protocol-buffer-editor',
#   '/google/vim-codereview',
#   '/google/vim-syncopate',
#   '/google/customer-match-upload-script',
#   '/google/grpc-kapt',
#   '/google/swift-package-manager',
#   '/google/webview-local-server',
#   '/google/dokka',
#   '/google/kleaver',
#   '/google/gocw',
#   '/google/pyctr'],
#  ['/google/compact_enc_det',
#   '/google/gif-for-cli',
#   '/google/blockly-android',
#   '/google/android-kerberos-authenticator',
#   '/google/uiimage-additions',
#   '/google/emitto',
#   '/google/stereo-magnification',
#   '/google/ldpush',
#   '/google/googlemock',
#   '/google/battery-historian',
#   '/google/graph_distillation',
#   '/google/byterun',
#   '/google/wear-sensors',
#   '/google/wear-screeninfo',
#   '/google/wear-displaylock',
#   '/google/cm-user-tool',
#   '/google/science-journal-arduino',
#   '/google/nel-collector',
#   '/google/google-api-cpp-client',
#   '/google/libcxx',
#   '/google/vectorio',
#   '/google/macops-molcodesignchecker',
#   '/google/macops-molcertificate',
#   '/google/open-vcdiff',
#   '/google/openjdk-kerberos',
#   '/google/astc-codec',
#   '/google/atlassian-addons-audit-sheet',
#   '/google/protorpc',
#   '/google/kiwi-solver',
#   '/google/cssi-blogasaurus'],
#  ['/google/gpu-emulation-stress-test',
#   '/google/rust-shell',
#   '/google/git-phabricator-mirror',
#   '/google/prometheus-slo-burn-example',
#   '/google/makerspace-partsbin',
#   '/google/bookbot-navigation',
#   '/google/chive-varying-prosody-icml-2019',
#   '/google/codeu-starter-project',
#   '/google/hrx-ruby',
#   '/google/android-wear-stitch-script',
#   '/google/pik',
#   '/google/lullaby',
#   '/google/squires',
#   '/google/web-activities',
#   '/google/keyczar',
#   '/google/neural-logic-machines',
#   '/google/sha1dc-jni',
#   '/google/flatui',
#   '/google/fplbase',
#   '/google/motive',
#   '/google/expt-analysis',
#   '/google/chromeosnavigationdemo',
#   '/google/github-issue-mover',
#   '/google/gjstest',
#   '/google/pikov',
#   '/google/godepq',
#   '/google/harpia',
#   '/google/pjflate',
#   '/google/us-altgr-intl',
#   '/google/error-prone-javac'],
#  ['/google/grassland',
#   '/google/gwt-charts',
#   '/google/git-patrol',
#   '/google/codewords',
#   '/google/horenso',
#   '/google/n-digit-mnist',
#   '/google/pagespeed-inslides',
#   '/google/go-structeditor',
#   '/google/agera',
#   '/google/navc',
#   '/google/ios-chatbot',
#   '/google/streetview-publish-client-libraries',
#   '/google/codemirror-mode-jsonnet',
#   '/google/fidi',
#   '/google/ps_log',
#   '/google/support-tools',
#   '/google/wikiloop-datasets',
#   '/google/heroku-buildpack-bazel',
#   '/google/skylark',
#   '/google/image-rebase',
#   '/google/zsldemo',
#   '/google/easy-grid',
#   '/google/keps',
#   '/google/hyou',
#   '/google/shipshape',
#   '/google/glslang',
#   '/google/quark',
#   '/google/vr180',
#   '/google/adiantum',
#   '/google/orismologer'],
#  ['/google/basicbokeh',
#   '/google/chord',
#   '/google/qpp',
#   '/google/google-visualization-python',
#   '/google/cordova-plugin-browsertab',
#   '/google/go-microservice-helpers',
#   '/google/go-cabfile',
#   '/google/node-sec-roadmap',
#   '/google/wwgc',
#   '/google/gdata-java-client',
#   '/google/magic-github-proxy',
#   '/google/emoji-segmenter',
#   '/google/gtm_load_timer',
#   '/google/vapso',
#   '/google/hangouts-chat-bot-cloud-function-nodejs-example',
#   '/google/googletv-android-samples',
#   '/google/supl-client',
#   '/google/dbm-lineitem-copier',
#   '/google/dcm-bulk-trafficking',
#   '/google/google-api-objectivec-client',
#   '/google/sshkey-audit',
#   '/google/mirandum',
#   '/google/radioreceiver',
#   '/google/contentbox',
#   '/google/meta_tagger',
#   '/google/btls',
#   '/google/opuscpp',
#   '/google/tfjs-mnist-workshop',
#   '/google/credstore',
#   '/google/khll-paper-experiments'],
#  ['/google/link022',
#   '/google/capillary',
#   '/google/active-qa',
#   '/google/python-dimond',
#   '/google/waze-ccp-gcp',
#   '/google/detectorgraph',
#   '/google/node-dependency-analysis',
#   '/google/watchpresenter',
#   '/google/syzygy',
#   '/google/oodle-demo',
#   '/google/codeu_project_2018',
#   '/google/physical-web',
#   '/google/rich-test-results',
#   '/google/dana',
#   '/google/ioweb2016',
#   '/google/libpam-policycache',
#   '/google/blue-green-deployment-controller',
#   '/google/cornerstone',
#   '/google/appengine-jenkins',
#   '/google/Safelight',
#   '/google/blkcgroup',
#   '/google/cpython-pt',
#   '/google/protobuf-dt',
#   '/google/cpp-netlib',
#   '/google/mysql',
#   '/google/sawbuck',
#   '/google/uribeacon',
#   '/google/ohmu',
#   '/google/recki-ct',
#   '/google/url_diff'],
#  ['/google/filesystem-proposal',
#   '/google/developer.github.com',
#   '/google/helloargdx',
#   '/google/nodejs-wiki',
#   '/google/emoji4unicode',
#   '/google/closure-linter',
#   '/google/ced',
#   '/google/blockly-devtools',
#   '/google/mozart',
#   '/google/universal-dash-transmuxer',
#   '/google/chrome-ssh-agent',
#   '/google/hilbert',
#   '/google/kasane',
#   '/google/python-yaml-config',
#   '/google/cloud-berg',
#   '/google/fast-optimized-community-significance',
#   '/google/binplist',
#   '/google/svalbard',
#   '/google/go-write',
#   '/google/cornerstoneWADOImageLoader',
#   '/google/cornerstoneTools',
#   '/google/sa360-bulk-editor',
#   '/google/music-synthesizer-for-android',
#   '/google/election-au-2016',
#   '/google/fancy-regex',
#   '/google/sg2im',
#   '/google/realestate10k',
#   '/google/domaintest',
#   '/google/asymproj_edge_dnn',
#   '/google/google-gdata']]

# %%
import itertools
flatten_list = list(itertools.chain(*repo_links))

# %%
len(flatten_list)
# Out:
# 1020

# %%
flatten_list = list(set(flatten_list))

# %%
len(flatten_list)
# Out:
# 1020

# %%
reposuffixes = pd.Series(flatten_list)

# %%
REPOS = reposuffixes.str[1:].to_list()

# %%
import os
import json
from typing import Dict, List, Optional, Union, cast
import requests

from env import github_token, github_username


headers = {"Authorization": f"token {github_token}", "User-Agent": github_username}

if headers["Authorization"] == "token " or headers["User-Agent"] == "":
    raise Exception(
        "You need to follow the instructions marked TODO in this script before trying to use it"
    )


def github_api_request(url: str) -> Union[List, Dict]:
    response = requests.get(url, headers=headers)
    response_data = response.json()
    if response.status_code != 200:
        raise Exception(
            f"Error response from github api! status code: {response.status_code}, "
            f"response: {json.dumps(response_data)}"
        )
    return response_data


def get_repo_language(repo: str) -> str:
    url = f"https://api.github.com/repos/{repo}"
    repo_info = github_api_request(url)
    if type(repo_info) is dict:
        repo_info = cast(Dict, repo_info)
        if "language" not in repo_info:
            raise Exception(
                "'language' key not round in response\n{}".format(json.dumps(repo_info))
            )
        return repo_info["language"]
    raise Exception(
        f"Expecting a dictionary response from {url}, instead got {json.dumps(repo_info)}"
    )


def get_repo_contents(repo: str) -> List[Dict[str, str]]:
    url = f"https://api.github.com/repos/{repo}/contents/"
    contents = github_api_request(url)
    if type(contents) is list:
        contents = cast(List, contents)
        return contents
    raise Exception(
        f"Expecting a list response from {url}, instead got {json.dumps(contents)}"
    )


def get_readme_download_url(files: List[Dict[str, str]]) -> str:
    """
    Takes in a response from the github api that lists the files in a repo and
    returns the url that can be used to download the repo's README file.
    """
    for file in files:
        if file["name"].lower().startswith("readme"):
            return file["download_url"]
    return ""


def process_repo(repo: str) -> Dict[str, str]:
    """
    Takes a repo name like "gocodeup/codeup-setup-script" and returns a
    dictionary with the language of the repo and the readme contents.
    """
    contents = get_repo_contents(repo)
    readme_download_url = get_readme_download_url(contents)
    if readme_download_url == "":
        readme_contents = ""
    else:
        readme_contents = requests.get(readme_download_url).text
    return {
        "repo": repo,
        "language": get_repo_language(repo),
        "readme_contents": readme_contents,
    }


def scrape_github_data() -> List[Dict[str, str]]:
    """
    Loop through all of the repos and process them. Returns the processed data.
    """
    return [process_repo(repo) for repo in REPOS]


if __name__ == "__main__":
    data = scrape_github_data()
    json.dump(data, open("data1.json", "w"), indent=1)

# %%
# run acquire.py script to create a .json file of all READMEs
# this takes awhile and produced an error message
# that I used my token too much
# but still produced complete .json file
scrape_github_data()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     361
# --> 362         self.sock = ssl_wrap_socket(
#     363             sock=conn,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data)
#     385         if HAS_SNI and server_hostname is not None:
# --> 386             return context.wrap_socket(sock, server_hostname=server_hostname)
#     387
#
# /usr/local/anaconda3/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# /usr/local/anaconda3/lib/python3.8/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# /usr/local/anaconda3/lib/python3.8/ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# TimeoutError: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     409             if read is False or not self._is_method_retryable(method):
# --> 410                 raise six.reraise(type(error), error, _stacktrace)
#     411             elif read is not None:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     361
# --> 362         self.sock = ssl_wrap_socket(
#     363             sock=conn,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data)
#     385         if HAS_SNI and server_hostname is not None:
# --> 386             return context.wrap_socket(sock, server_hostname=server_hostname)
#     387
#
# /usr/local/anaconda3/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# /usr/local/anaconda3/lib/python3.8/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# /usr/local/anaconda3/lib/python3.8/ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# ProtocolError: ('Connection aborted.', TimeoutError(60, 'Operation timed out'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-58-d3dc72e84612> in <module>
#       3 # that I used my token too much
#       4 # but still produced complete .json file
# ----> 5 scrape_github_data()
#
# <ipython-input-57-36d68cd5d72d> in scrape_github_data()
#      85     Loop through all of the repos and process them. Returns the processed data.
#      86     """
# ---> 87     return [process_repo(repo) for repo in REPOS]
#      88
#      89
#
# <ipython-input-57-36d68cd5d72d> in <listcomp>(.0)
#      85     Loop through all of the repos and process them. Returns the processed data.
#      86     """
# ---> 87     return [process_repo(repo) for repo in REPOS]
#      88
#      89
#
# <ipython-input-57-36d68cd5d72d> in process_repo(repo)
#      73         readme_contents = ""
#      74     else:
# ---> 75         readme_contents = requests.get(readme_download_url).text
#      76     return {
#      77         "repo": repo,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', TimeoutError(60, 'Operation timed out'))

# %%
f = open('data1.json')

# %%
data = json.load(f)

# %%
df = pd.DataFrame(data)

# %%
# create DF of all READMEs
df.head(2)
# Out:
#                  repo language  \
# 0      google/ci_edit   Python
# 1  google/bms-toolkit    Shell
#
#                                      readme_contents
# 0  # What is ci_edit\n\nci_edit is a text editor....
# 1  # bms-toolkit\n\nToolkit for installing and cr...

# %%
df.to_csv('google_readmes1020.csv')
