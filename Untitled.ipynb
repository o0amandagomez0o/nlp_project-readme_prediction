# %%
import os
import json
from typing import Dict, List, Optional, Union, cast
import requests

from env import github_token, github_username

import acquire_zach as az

import numpy as np
import pandas as pd

# acquire
from requests import get
from bs4 import BeautifulSoup
from time import sleep
import os

# prepare
import unicodedata
import re
import json
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

# explore
from sklearn.model_selection import train_test_split
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# model
from pprint import pprint
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import confusion_matrix, classification_report

# %%
df = az.scrape_github_data()

# %%
df
# Out:
# [{'repo': 'gocodeup/codeup-setup-script',
#   'language': 'Shell',
#   'readme_contents': '# Codeup Setup Script\n\nSetup script for Codeup students\' laptops to install the all the tools we will\nneed for the java course. We will install the following:\n\n- [xcode](https://developer.apple.com/xcode/features/): command line tools for\n  macs\n- [brew](http://brew.sh/): package manager for macs\n- [java](https://en.wikipedia.org/wiki/Java_(programming_language))\n- [tomcat](http://tomcat.apache.org/): the java webserver\n- [maven](https://maven.apache.org/): a java dependency and build management tool\n- [mysql](https://www.mysql.com/): the database we\'ll use for the class\n- [node js](https://nodejs.org/en/): a JavaScript runtime outside the browser\n- [npm](https://www.npmjs.com/): a package manager for JavaScript\n- [intellij](https://www.jetbrains.com/idea/): a Java IDE\n\nIn addition, we will:\n\n- setup ssh keys for the student\'s laptop and guide them through the process of\n  linking their ssh key to their Github account.\n- Setup a global gitignore file and set the default commit editor to `nano`\n  (only if these are not already set)\n\n## For Students\n\nCopy and paste the following in your terminal:\n\n```\nbash -c "$(curl -sS https://raw.githubusercontent.com/gocodeup/codeup-setup-script/master/install.sh)"\n```\n\n## Note for Instructors\n\nIf students already have and `id_rsa` ssh key generated the script will *not*\ntry to generate a new ones, and you will need to walk them through the process\nof adding their existing key to Github.\n\nThe following should do the trick if they already have a ssh key pair, but it\'s\nnot wired up to Github.\n\n```bash\npbcopy < ~/.ssh/id_rsa.pub\nopen https://github.com/settings/ssh\n```\n'},
#  {'repo': 'gocodeup/movies-application',
#   'language': 'JavaScript',
#   'readme_contents': '# Movies Application\n\nFor this project, we will be building a single page movie application (SPA). It\nwill allow users to add, edit, and delete movies, as well as rate them. We will\nbe using [`json-server`](https://github.com/typicode/json-server) to mock a\ndatabase and our backend, so that we can just worry about the front end and AJAX\nrequests.\n\nThe webpack dev server is configured to watch for changes both in the javascript\nsource, as well as the `public` directory. Whenever changes are detected, the\npage will be reloaded. It will also proxy any requests that start with `/api` to\nlocalhost:3000, which is where json-server is configured run.\n\n`json-server` is configured to have a delay of 1.2 seconds, so you can see what\nyour application might actually look like, instead of serving instantaneous\nreponses. You can modify this behavior by changing (or removing) the number\nafter the `-d` flag inside of the npm `dev` script.\n\n## Setup\n\n1. Fork this repository to your own github account or your github organization.\n\n1. Clone your fork locally into your computer.\n\n1. Run `npm install`\n\n1. Run `npm run build`\n\n1. Run `npm run dev` and visit\n   [http://localhost:1313/](http://localhost:1313/) in your browser. Open up\n   the console and inspect the output.\n\n## Development\n\nIn general, you should have the development web server (`npm run dev`) running\nwhile you are working on the project. You should view your project through\nhttp://localhost:1313, **not** from IntelliJ\'s web server, or by dragging the\nfile(s) into chrome. As you make changes to your source files, all you need to\ndo is save the file, and the website will be live reloaded.\n\nTake a look at the `src/index.js` file to get started. You will notice it has\nexamples of importing and requiring separate javascript files. Regardless of\nwhich you choose to use, you should pick one and use it throughout your code\nbase, don\'t mix and match the two.\n\nThe file `src/api.js` also contains an example api request. You can\nreference this to get started building out the parts of your application that\ninteract with the api.\n\nThe `db.json` file contains your "database". You can edit this file directly to\nmake changes to your data, and this file will be updated if you make api\nrequests that modify the data.\n\nThe server will serve files from the `public` directory, meaning any files\noutside of `public` will not be visible. This means if you have any frontend\nassets (e.g. bootstrap, or images) they will need to be in the `public`\ndirectory.\n\n## Specification\n\nYour application should:\n\nOn page load:\n\n- Display a "loading..." message\n- Make an ajax request to get a listing of all the movies\n- When the initial ajax request comes back, remove the "loading..." message\n  and replace it with HTML generated from the json response your code\n  receives\n\nAllow users to add new movies\n\n- Create a form for adding a new movie that has fields for the movie\'s title\n  and rating\n- When the form is submitted, the page should **not** reload / refresh,\n  instead, your javascript should make a POST request to `/api/movies` with the\n  information the user put into the form\n\nAllow users to edit existing movies\n\n- Give users the option to edit an existing movie\n- A form should be pre-populated with the selected movie\'s details\n- Like creating a movie, this should not involve any page reloads, instead\n  your javascript code should make an ajax request when the form is\n  submitted.\n\nDelete movies\n\n- Each movie should have a "delete" button\n- When this button is clicked, your javascript should send a `DELETE` request\n\n### Bonuses\n\n- Add a `disabled` attribute to buttons while their corresponding ajax request\n  is still pending.\n- Show a loading animation instead of just text that says "loading..."\n- Use modals for the creating and editing movie forms\n- Add a `genre` property to every movie\n- Allow us ...
#  {'repo': 'torvalds/linux',
#   'language': 'C',
#   'readme_contents': 'Linux kernel\n============\n\nThere are several guides for kernel developers and users. These guides can\nbe rendered in a number of formats, like HTML and PDF. Please read\nDocumentation/admin-guide/README.rst first.\n\nIn order to build the documentation, use ``make htmldocs`` or\n``make pdfdocs``.  The formatted documentation can also be read online at:\n\n    https://www.kernel.org/doc/html/latest/\n\nThere are various text files in the Documentation/ subdirectory,\nseveral of them using the Restructured Text markup notation.\n\nPlease read the Documentation/process/changes.rst file, as it contains the\nrequirements for building and running the kernel, and information about\nthe problems which may result by upgrading your kernel.\n'}]

# %%
urls = []
    for i in range(1,68):
    # first page for most starred repos on GH
    url = f'https://https://github.com/google?page={i}''
    urls.append(url)
return urls
# Out:
#   File "<ipython-input-2-1b9f22802c79>", line 2
#     for i in range(1,68):
#     ^
# IndentationError: unexpected indent

# %%
# These are the headers from Zach's acquire module, so you will have to finish the TODOs there before this works
headers = acquire.headers
# Visit https://docs.github.com/en/rest/reference/search#search-repositories for more information on the different parameters
endpoint = "https://api.github.com/search/repositories"
query = "bootcamp in:name"
sort = "stars"
per_page = 100
order = "desc"
page = 1
response = req.get(f"{endpoint}?q={query}&sort={sort}&per_page={per_page}&order={order}&page={page}", headers=headers)
payload = response.json()
payload['items']

# %%
# These are the headers from Zach's acquire module, so you will have to finish the TODOs there before this works
headers = az.headers
# Visit https://docs.github.com/en/rest/reference/search#search-repositories for more information on the different parameters
endpoint = "https://api.github.com/users/google"
per_page = 100
page = 1
response = requests.get(f"{endpoint}?per_page={per_page}&page={page}", headers=headers)
payload = response.json()
payload['items']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-6797bcd96a97> in <module>
#       7 response = requests.get(f"{endpoint}?per_page={per_page}&page={page}", headers=headers)
#       8 payload = response.json()
# ----> 9 payload['items']
#
# KeyError: 'items'

# %%
headers = az.headers
endpoint = "https://api.github.com/search/repositories"
query = "google in:name"
sort = "stars"
per_page = 100
order = "desc"
page = 1
#Make the request
response = requests.get(f"{endpoint}?q={query}&sort={sort}&per_page={per_page}&order={order}&page={page}", headers=headers)
payload = response.json()
payload['items']
# Out:
# [{'id': 24953448,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNDk1MzQ0OA==',
#   'name': 'material-design-icons',
#   'full_name': 'google/material-design-icons',
#   'private': False,
#   'owner': {'login': 'google',
#    'id': 1342004,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEzNDIwMDQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1342004?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/google',
#    'html_url': 'https://github.com/google',
#    'followers_url': 'https://api.github.com/users/google/followers',
#    'following_url': 'https://api.github.com/users/google/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/google/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/google/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/google/subscriptions',
#    'organizations_url': 'https://api.github.com/users/google/orgs',
#    'repos_url': 'https://api.github.com/users/google/repos',
#    'events_url': 'https://api.github.com/users/google/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/google/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/google/material-design-icons',
#   'description': 'Material Design icons by Google',
#   'fork': False,
#   'url': 'https://api.github.com/repos/google/material-design-icons',
#   'forks_url': 'https://api.github.com/repos/google/material-design-icons/forks',
#   'keys_url': 'https://api.github.com/repos/google/material-design-icons/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/google/material-design-icons/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/google/material-design-icons/teams',
#   'hooks_url': 'https://api.github.com/repos/google/material-design-icons/hooks',
#   'issue_events_url': 'https://api.github.com/repos/google/material-design-icons/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/google/material-design-icons/events',
#   'assignees_url': 'https://api.github.com/repos/google/material-design-icons/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/google/material-design-icons/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/google/material-design-icons/tags',
#   'blobs_url': 'https://api.github.com/repos/google/material-design-icons/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/google/material-design-icons/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/google/material-design-icons/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/google/material-design-icons/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/google/material-design-icons/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/google/material-design-icons/languages',
#   'stargazers_url': 'https://api.github.com/repos/google/material-design-icons/stargazers',
#   'contributors_url': 'https://api.github.com/repos/google/material-design-icons/contributors',
#   'subscribers_url': 'https://api.github.com/repos/google/material-design-icons/subscribers',
#   'subscription_url': 'https://api.github.com/repos/google/material-design-icons/subscription',
#   'commits_url': 'https://api.github.com/repos/google/material-design-icons/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/google/material-design-icons/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/google/material-design-icons/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/google/material-design-icons/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/google/material-design-icons/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/google/material-design-icons/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/google/material-design-icons/merges',
#   'archive_url': 'https://api.github.com/repos/google/material-design-icons/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/google/material-design-icons/downloads',
#   'issues_url': 'https://api.github.com/repos/google/material-design-icons/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/google/material-design-icons/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/google/material-design-icons/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/google/material-design-icons/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/google/material-design-icons/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/google/material-design-icons/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/google/material-design-icons/deployments',
#   'created_at': '2014-10-08T18:01:28Z',
#   'updated_at': '2021-05-06T19:32:23Z',
#   'pushed_at': '2021-04-30T11:28:14Z',
#   'git_url': 'git://github.com/google/material-design-icons.git',
#   'ssh_url': 'git@github.com:google/material-design-icons.git',
#   'clone_url': 'https://github.com/google/material-design-icons.git',
#   'svn_url': 'https://github.com/google/material-design-icons',
#   'homepage': 'http://google.github.io/material-design-icons/',
#   'size': 101045,
#   'stargazers_count': 42766,
#   'watchers_count': 42766,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': False,
#   'has_wiki': True,
#   'has_pages': True,
#   'forks_count': 8673,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 310,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'forks': 8673,
#   'open_issues': 310,
#   'watchers': 42766,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True},
#   'score': 1.0},
#  {'id': 20300177,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMDMwMDE3Nw==',
#   'name': 'guava',
#   'full_name': 'google/guava',
#   'private': False,
#   'owner': {'login': 'google',
#    'id': 1342004,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEzNDIwMDQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1342004?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/google',
#    'html_url': 'https://github.com/google',
#    'followers_url': 'https://api.github.com/users/google/followers',
#    'following_url': 'https://api.github.com/users/google/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/google/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/google/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/google/subscriptions',
#    'organizations_url': 'https://api.github.com/users/google/orgs',
#    'repos_url': 'https://api.github.com/users/google/repos',
#    'events_url': 'https://api.github.com/users/google/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/google/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/google/guava',
#   'description': 'Google core libraries for Java',
#   'fork': False,
#   'url': 'https://api.github.com/repos/google/guava',
#   'forks_url': 'https://api.github.com/repos/google/guava/forks',
#   'keys_url': 'https://api.github.com/repos/google/guava/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/google/guava/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/google/guava/teams',
#   'hooks_url': 'https://api.github.com/repos/google/guava/hooks',
#   'issue_events_url': 'https://api.github.com/repos/google/guava/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/google/guava/events',
#   'assignees_url': 'https://api.github.com/repos/google/guava/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/google/guava/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/google/guava/tags',
#   'blobs_url': 'https://api.github.com/repos/google/guava/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/google/guava/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/google/guava/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/google/guava/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/google/guava/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/google/guava/languages',
#   'stargazers_url': 'https://api.github.com/repos/google/guava/stargazers',
#   'contributors_url': 'https://api.github.com/repos/google/guava/contributors',
#   'subscribers_url': 'https://api.github.com/repos/google/guava/subscribers',
#   'subscription_url': 'https://api.github.com/repos/google/guava/subscription',
#   'commits_url': 'https://api.github.com/repos/google/guava/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/google/guava/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/google/guava/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/google/guava/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/google/guava/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/google/guava/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/google/guava/merges',
#   'archive_url': 'https://api.github.com/repos/google/guava/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/google/guava/downloads',
#   'issues_url': 'https://api.github.com/repos/google/guava/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/google/guava/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/google/guava/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/google/guava/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/google/guava/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/google/guava/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/google/guava/deployments',
#   'created_at': '2014-05-29T16:23:17Z',
#   'updated_at': '2021-05-06T21:12:01Z',
#   'pushed_at': '2021-05-06T20:51:04Z',
#   'git_url': 'git://github.com/google/guava.git',
#   'ssh_url': 'git@github.com:google/guava.git',
#   'clone_url': 'https://github.com/google/guava.git',
#   'svn_url': 'https://github.com/google/guava',
#   'homepage': '',
#   'size': 323573,
#   'stargazers_count': 41054,
#   'watchers_count': 41054,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': True,
#   'forks_count': 9166,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 706,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'forks': 9166,
#   'open_issues': 706,
#   'watchers': 41054,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True},
#   'score': 1.0},
#  {'id': 29268051,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyOTI2ODA1MQ==',
#   'name': 'material-design-lite',
#   'full_name': 'google/material-design-lite',
#   'private': False,
#   'owner': {'login': 'google',
#    'id': 1342004,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEzNDIwMDQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1342004?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/google',
#    'html_url': 'https://github.com/google',
#    'followers_url': 'https://api.github.com/users/google/followers',
#    'following_url': 'https://api.github.com/users/google/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/google/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/google/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/google/subscriptions',
#    'organizations_url': 'https://api.github.com/users/google/orgs',
#    'repos_url': 'https://api.github.com/users/google/repos',
#    'events_url': 'https://api.github.com/users/google/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/google/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/google/material-design-lite',
#   'description': 'Material Design Components in HTML/CSS/JS',
#   'fork': False,
#   'url': 'https://api.github.com/repos/google/material-design-lite',
#   'forks_url': 'https://api.github.com/repos/google/material-design-lite/forks',
#   'keys_url': 'https://api.github.com/repos/google/material-design-lite/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/google/material-design-lite/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/google/material-design-lite/teams',
#   'hooks_url': 'https://api.github.com/repos/google/material-design-lite/hooks',
#   'issue_events_url': 'https://api.github.com/repos/google/material-design-lite/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/google/material-design-lite/events',
#   'assignees_url': 'https://api.github.com/repos/google/material-design-lite/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/google/material-design-lite/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/google/material-design-lite/tags',
#   'blobs_url': 'https://api.github.com/repos/google/material-design-lite/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/google/material-design-lite/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/google/material-design-lite/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/google/material-design-lite/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/google/material-design-lite/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/google/material-design-lite/languages',
#   'stargazers_url': 'https://api.github.com/repos/google/material-design-lite/stargazers',
#   'contributors_url': 'https://api.github.com/repos/google/material-design-lite/contributors',
#   'subscribers_url': 'https://api.github.com/repos/google/material-design-lite/subscribers',
#   'subscription_url': 'https://api.github.com/repos/google/material-design-lite/subscription',
#   'commits_url': 'https://api.github.com/repos/google/material-design-lite/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/google/material-design-lite/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/google/material-design-lite/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/google/material-design-lite/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/google/material-design-lite/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/google/material-design-lite/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/google/material-design-lite/merges',
#   'archive_url': 'https://api.github.com/repos/google/material-design-lite/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/google/material-design-lite/downloads',
#   'issues_url': 'https://api.github.com/repos/google/material-design-lite/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/google/material-design-lite/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/google/material-design-lite/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/google/material-design-lite/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/google/material-design-lite/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/google/material-design-lite/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/google/material-design-lite/deployments',
#   'created_at': '2015-01-14T22:01:33Z',
#   'updated_at': '2021-05-06T22:37:38Z',
#   'pushed_at': '2021-03-18T20:36:47Z',
#   'git_url': 'git://github.com/google/material-design-lite.git',
#   'ssh_url': 'git@github.com:google/material-design-lite.git',
#   'clone_url': 'https://github.com/google/material-design-lite.git',
#   'svn_url': 'https://github.com/google/material-design-lite',
#   'homepage': 'https://getmdl.io',
#   'size': 56968,
#   'stargazers_count': 31765,
#   'watchers_count': 31765,
#   'language': 'HTML',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': False,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 5225,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 378,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'forks': 5225,
#   'open_issues': 378,
#   'watchers': 31765,
#   'default_branch': 'mdl-1.x',
#   'permissions': {'admin': False, 'push': False, 'pull': True},
#   'score': 1.0},
#  {'id': 154747577,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNTQ3NDc1Nzc=',
#   'name': 'bert',
#   'full_name': 'google-research/bert',
#   'private': False,
#   'owner': {'login': 'google-research',
#    'id': 43830688,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQzODMwNjg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43830688?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/google-research',
#    'html_url': 'https://github.com/google-research',
#    'followers_url': 'https://api.github.com/users/google-research/followers',
#    'following_url': 'https://api.github.com/users/google-research/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/google-research/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/google-research/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/google-research/subscriptions',
#    'organizations_url': 'https://api.github.com/users/google-research/orgs',
#    'repos_url': 'https://api.github.com/users/google-research/repos',
#    'events_url': 'https://api.github.com/users/google-research/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/google-research/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/google-research/bert',
#   'description': 'TensorFlow code and pre-trained models for BERT',
#   'fork': False,
#   'url': 'https://api.github.com/repos/google-research/bert',
#   'forks_url': 'https://api.github.com/repos/google-research/bert/forks',
#   'keys_url': 'https://api.github.com/repos/google-research/bert/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/google-research/bert/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/google-research/bert/teams',
#   'hooks_url': 'https://api.github.com/repos/google-research/bert/hooks',
#   'issue_events_url': 'https://api.github.com/repos/google-research/bert/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/google-research/bert/events',
#   'assignees_url': 'https://api.github.com/repos/google-research/bert/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/google-research/bert/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/google-research/bert/tags',
#   'blobs_url': 'https://api.github.com/repos/google-research/bert/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/google-research/bert/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/google-research/bert/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/google-research/bert/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/google-research/bert/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/google-research/bert/languages',
#   'stargazers_url': 'https://api.github.com/repos/google-research/bert/stargazers',
#   'contributors_url': 'https://api.github.com/repos/google-research/bert/contributors',
#   'subscribers_url': 'https://api.github.com/repos/google-research/bert/subscribers',
#   'subscription_url': 'https://api.github.com/repos/google-research/bert/subscription',
#   'commits_url': 'https://api.github.com/repos/google-research/bert/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/google-research/bert/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/google-research/bert/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/google-research/bert/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/google-research/bert/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/google-research/bert/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/google-research/bert/merges',
#   'archive_url': 'https://api.github.com/repos/google-research/bert/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/google-research/bert/downloads',
#   'issues_url': 'https://api.github.com/repos/google-research/bert/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/google-research/bert/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/google-research/bert/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/google-research/bert/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/google-research/bert/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/google-research/bert/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/google-research/bert/deployments',
#   'created_at': '2018-10-25T22:57:34Z',
#   'updated_at': '2021-05-06T22:24:38Z',
#   'pushed_at': '2021-04-24T13:12:16Z',
#   'git_url': 'git://github.com/google-research/bert.git',
#   'ssh_url': 'git@github.com:google-research/bert.git',
#   'clone_url': 'https://github.com/google-research/bert.git',
#   'svn_url': 'https://github.com/google-research/bert',
#   'homepage': 'https://arxiv.org/abs/1810.04805',
#   'size': 317,
#   'stargazers_count': 27853,
#   'watchers_count': 27853,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 7904,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 791,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'forks': 7904,
#   'open_issues': 791,
#   'watchers': 27853,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True},
#   'score': 1.0},
#  {'id': 35969061,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNTk2OTA2MQ==',
#   'name': 'styleguide',
#   'full_name': 'google/styleguide',
#   'private': False,
#   'owner': {'login': 'google',
#    'id': 1342004,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEzNDIwMDQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1342004?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/google',
#    'html_url': 'https://github.com/google',
#    'followers_url': 'https://api.github.com/users/google/followers',
#    'following_url': 'https://api.github.com/users/google/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/google/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/google/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/google/subscriptions',
#    'organizations_url': 'https://api.github.com/users/google/orgs',
#    'repos_url': 'https://api.github.com/users/google/repos',
#    'events_url': 'https://api.github.com/users/google/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/google/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/google/styleguide',
#   'description': 'Style guides for Google-originated open-source projects',
#   'fork': False,
#   'url': 'https://api.github.com/repos/google/styleguide',
#   'forks_url': 'https://api.github.com/repos/google/styleguide/forks',
#   'keys_url': 'https://api.github.com/repos/google/styleguide/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/google/styleguide/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/google/styleguide/teams',
#   'hooks_url': 'https://api.github.com/repos/google/styleguide/hooks',
#   'issue_events_url': 'https://api.github.com/repos/google/styleguide/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/google/styleguide/events',
#   'assignees_url': 'https://api.github.com/repos/google/styleguide/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/google/styleguide/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/google/styleguide/tags',
#   'blobs_url': 'https://api.github.com/repos/google/styleguide/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/google/styleguide/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/google/styleguide/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/google/styleguide/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/google/styleguide/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/google/styleguide/languages',
#   'stargazers_url': 'https://api.github.com/repos/google/styleguide/stargazers',
#   'contributors_url': 'https://api.github.com/repos/google/styleguide/contributors',
#   'subscribers_url': 'https://api.github.com/repos/google/styleguide/subscribers',
#   'subscription_url': 'https://api.github.com/repos/google/styleguide/subscription',
#   'commits_url': 'https://api.github.com/repos/google/styleguide/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/google/styleguide/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/google/styleguide/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/google/styleguide/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/google/styleguide/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/google/styleguide/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/google/styleguide/merges',
#   'archive_url': 'https://api.github.com/repos/google/styleguide/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/google/styleguide/downloads',
#   'issues_url': 'https://api.github.com/repos/google/styleguide/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/google/styleguide/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/google/styleguide/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/google/styleguide/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/google/styleguide/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/google/styleguide/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/google/styleguide/deployments',
#   'created_at': '2015-05-20T19:18:59Z',
#   'updated_at': '2021-05-06T20:50:12Z',
#   'pushed_at': '2021-04-26T11:11:26Z',
#   'git_url': 'git://github.com/google/styleguide.git',
#   'ssh_url': 'git@github.com:google/styleguide.git',
#   'clone_url': 'https://github.com/google/styleguide.git',
#   'svn_url': 'https://github.com/google/styleguide',
#   'homepage': 'https://google.github.io/styleguide/',
#   'size': 2330,
#   'stargazers_count': 27566,
#   'watchers_count': 27566,
#   'language': 'HTML',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': False,
#   'has_wiki': False,
#   'has_pages': True,
#   'forks_count': 10570,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 293,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'forks': 10570,
#   'open_issues': 293,
#   'watchers': 27566,
#   'default_branch': 'gh-pages',
#   'permissions': {'admin': False, 'push': False, 'pull': True},
#   'score': 1.0},
#  {'id': 23405758,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMzQwNTc1OA==',
#   'name': 'leveldb',
#   'full_name': 'google/leveldb',
#   'private': False,
#   'owner': {'login': 'google',
#    'id': 1342004,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEzNDIwMDQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1342004?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/google',
#    'html_url': 'https://github.com/google',
#    'followers_url': 'https://api.github.com/users/google/followers',
#    'following_url': 'https://api.github.com/users/google/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/google/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/google/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/google/subscriptions',
#    'organizations_url': 'https://api.github.com/users/google/orgs',
#    'repos_url': 'https://api.github.com/users/google/repos',
#    'events_url': 'https://api.github.com/users/google/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/google/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/google/leveldb',
#   'description': 'LevelDB is a fast key-value storage library written at Google that provides an ordered mapping from string keys to string values.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/google/leveldb',
#   'forks_url': 'https://api.github.com/repos/google/leveldb/forks',
#   'keys_url': 'https://api.github.com/repos/google/leveldb/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/google/leveldb/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/google/leveldb/teams',
#   'hooks_url': 'https://api.github.com/repos/google/leveldb/hooks',
#   'issue_events_url': 'https://api.github.com/repos/google/leveldb/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/google/leveldb/events',
#   'assignees_url': 'https://api.github.com/repos/google/leveldb/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/google/leveldb/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/google/leveldb/tags',
#   'blobs_url': 'https://api.github.com/repos/google/leveldb/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/google/leveldb/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/google/leveldb/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/google/leveldb/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/google/leveldb/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/google/leveldb/languages',
#   'stargazers_url': 'https://api.github.com/repos/google/leveldb/stargazers',
#   'contributors_url': 'https://api.github.com/repos/google/leveldb/contributors',
#   'subscribers_url': 'https://api.github.com/repos/google/leveldb/subscribers',
#   'subscription_url': 'https://api.github.com/repos/google/leveldb/subscription',
#   'commits_url': 'https://api.github.com/repos/google/leveldb/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/google/leveldb/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/google/leveldb/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/google/leveldb/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/google/leveldb/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/google/leveldb/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/google/leveldb/merges',
#   'archive_url': 'https://api.github.com/repos/google/leveldb/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/google/leveldb/downloads',
#   'issues_url': 'https://api.github.com/repos/google/leveldb/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/google/leveldb/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/google/leveldb/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/google/leveldb/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/google/leveldb/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/google/leveldb/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/google/leveldb/deployments',
#   'created_at': '2014-08-27T21:17:52Z',
#   'updated_at': '2021-05-06T21:46:16Z',
#   'pushed_at': '2021-05-02T06:17:22Z',
#   'git_url': 'git://github.com/google/leveldb.git',
#   'ssh_url': 'git@github.com:google/leveldb.git',
#   'clone_url': 'https://github.com/google/leveldb.git',
#   'svn_url': 'https://github.com/google/leveldb',
#   'homepage': '',
#   'size': 1500,
#   'stargazers_count': 24614,
#   'watchers_count': 24614,
#   'language': 'C++',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': False,
#   'has_wiki': False,
#   'has_pages': False,
#   'forks_count': 5534,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 202,
#   'license': {'key': 'bsd-3-clause',
#    'name': 'BSD 3-Clause "New" or "Revised" License',
#    'spdx_id': 'BSD-3-Clause',
#    'url': 'https://api.github.com/licenses/bsd-3-clause',
#    'node_id': 'MDc6TGljZW5zZTU='},
#   'forks': 5534,
#   'open_issues': 202,
#   'watchers': 24614,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True},
#   'score': 1.0},
#  {'id': 39840932,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTg0MDkzMg==',
#   'name': 'googletest',
#   'full_name': 'google/googletest',
#   'private': False,
#   'owner': {'login': 'google',
#    'id': 1342004,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEzNDIwMDQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1342004?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/google',
#    'html_url': 'https://github.com/google',
#    'followers_url': 'https://api.github.com/users/google/followers',
#    'following_url': 'https://api.github.com/users/google/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/google/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/google/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/google/subscriptions',
#    'organizations_url': 'https://api.github.com/users/google/orgs',
#    'repos_url': 'https://api.github.com/users/google/repos',
#    'events_url': 'https://api.github.com/users/google/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/google/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/google/googletest',
#   'description': 'GoogleTest - Google Testing and Mocking Framework',
#   'fork': False,
#   'url': 'https://api.github.com/repos/google/googletest',
#   'forks_url': 'https://api.github.com/repos/google/googletest/forks',
#   'keys_url': 'https://api.github.com/repos/google/googletest/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/google/googletest/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/google/googletest/teams',
#   'hooks_url': 'https://api.github.com/repos/google/googletest/hooks',
#   'issue_events_url': 'https://api.github.com/repos/google/googletest/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/google/googletest/events',
#   'assignees_url': 'https://api.github.com/repos/google/googletest/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/google/googletest/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/google/googletest/tags',
#   'blobs_url': 'https://api.github.com/repos/google/googletest/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/google/googletest/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/google/googletest/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/google/googletest/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/google/googletest/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/google/googletest/languages',
#   'stargazers_url': 'https://api.github.com/repos/google/googletest/stargazers',
#   'contributors_url': 'https://api.github.com/repos/google/googletest/contributors',
#   'subscribers_url': 'https://api.github.com/repos/google/googletest/subscribers',
#   'subscription_url': 'https://api.github.com/repos/google/googletest/subscription',
#   'commits_url': 'https://api.github.com/repos/google/googletest/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/google/googletest/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/google/googletest/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/google/googletest/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/google/googletest/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/google/googletest/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/google/googletest/merges',
#   'archive_url': 'https://api.github.com/repos/google/googletest/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/google/googletest/downloads',
#   'issues_url': 'https://api.github.com/repos/google/googletest/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/google/googletest/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/google/googletest/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/google/googletest/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/google/googletest/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/google/googletest/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/google/googletest/deployments',
#   'created_at': '2015-07-28T15:07:53Z',
#   'updated_at': '2021-05-06T22:36:58Z',
#   'pushed_at': '2021-05-05T14:57:17Z',
#   'git_url': 'git://github.com/google/googletest.git',
#   'ssh_url': 'git@github.com:google/googletest.git',
#   'clone_url': 'https://github.com/google/googletest.git',
#   'svn_url': 'https://github.com/google/googletest',
#   'homepage': 'https://google.github.io/googletest/',
#   'size': 9642,
#   'stargazers_count': 21923,
#   'watchers_count': 21923,
#   'language': 'C++',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': False,
#   'has_wiki': False,
#   'has_pages': True,
#   'forks_count': 7426,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 168,
#   'license': {'key': 'bsd-3-clause',
#    'name': 'BSD 3-Clause "New" or "Revised" License',
#    'spdx_id': 'BSD-3-Clause',
#    'url': 'https://api.github.com/licenses/bsd-3-clause',
#    'node_id': 'MDc6TGljZW5zZTU='},
#   'forks': 7426,
#   'open_issues': 168,
#   'watchers': 21923,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True},
#   'score': 1.0},
#  {'id': 18347476,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxODM0NzQ3Ng==',
#   'name': 'iosched',
#   'full_name': 'google/iosched',
#   'private': False,
#   'owner': {'login': 'google',
#    'id': 1342004,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEzNDIwMDQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1342004?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/google',
#    'html_url': 'https://github.com/google',
#    'followers_url': 'https://api.github.com/users/google/followers',
#    'following_url': 'https://api.github.com/users/google/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/google/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/google/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/google/subscriptions',
#    'organizations_url': 'https://api.github.com/users/google/orgs',
#    'repos_url': 'https://api.github.com/users/google/repos',
#    'events_url': 'https://api.github.com/users/google/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/google/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/google/iosched',
#   'description': 'The Google I/O 2019 Android App',
#   'fork': False,
#   'url': 'https://api.github.com/repos/google/iosched',
#   'forks_url': 'https://api.github.com/repos/google/iosched/forks',
#   'keys_url': 'https://api.github.com/repos/google/iosched/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/google/iosched/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/google/iosched/teams',
#   'hooks_url': 'https://api.github.com/repos/google/iosched/hooks',
#   'issue_events_url': 'https://api.github.com/repos/google/iosched/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/google/iosched/events',
#   'assignees_url': 'https://api.github.com/repos/google/iosched/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/google/iosched/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/google/iosched/tags',
#   'blobs_url': 'https://api.github.com/repos/google/iosched/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/google/iosched/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/google/iosched/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/google/iosched/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/google/iosched/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/google/iosched/languages',
#   'stargazers_url': 'https://api.github.com/repos/google/iosched/stargazers',
#   'contributors_url': 'https://api.github.com/repos/google/iosched/contributors',
#   'subscribers_url': 'https://api.github.com/repos/google/iosched/subscribers',
#   'subscription_url': 'https://api.github.com/repos/google/iosched/subscription',
#   'commits_url': 'https://api.github.com/repos/google/iosched/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/google/iosched/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/google/iosched/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/google/iosched/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/google/iosched/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/google/iosched/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/google/iosched/merges',
#   'archive_url': 'https://api.github.com/repos/google/iosched/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/google/iosched/downloads',
#   'issues_url': 'https://api.github.com/repos/google/iosched/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/google/iosched/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/google/iosched/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/google/iosched/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/google/iosched/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/google/iosched/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/google/iosched/deployments',
#   'created_at': '2014-04-01T22:40:40Z',
#   'updated_at': '2021-05-06T15:50:44Z',
#   'pushed_at': '2021-02-14T16:07:15Z',
#   'git_url': 'git://github.com/google/iosched.git',
#   'ssh_url': 'git@github.com:google/iosched.git',
#   'clone_url': 'https://github.com/google/iosched.git',
#   'svn_url': 'https://github.com/google/iosched',
#   'homepage': 'https://play.google.com/store/apps/details?id=com.google.samples.apps.iosched',
#   'size': 55963,
#   'stargazers_count': 20358,
#   'watchers_count': 20358,
#   'language': 'Kotlin',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'forks_count': 6114,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 50,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'forks': 6114,
#   'open_issues': 50,
#   'watchers': 20358,
#   'default_branch': 'main',
#   'permissions': {'admin': False, 'push': False, 'pull': True},
#   'score': 1.0},
#  {'id': 32538871,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMjUzODg3MQ==',
#   'name': 'gson',
#   'full_name': 'google/gson',
#   'private': False,
#   'owner': {'login': 'google',
#    'id': 1342004,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEzNDIwMDQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1342004?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/google',
#    'html_url': 'https://github.com/google',
#    'followers_url': 'https://api.github.com/users/google/followers',
#    'following_url': 'https://api.github.com/users/google/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/google/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/google/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/google/subscriptions',
#    'organizations_url': 'https://api.github.com/users/google/orgs',
#    'repos_url': 'https://api.github.com/users/google/repos',
#    'events_url': 'https://api.github.com/users/google/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/google/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/google/gson',
#   'description': 'A Java serialization/deserialization library to convert Java Objects into JSON and back',
#   'fork': False,
#   'url': 'https://api.github.com/repos/google/gson',
#   'forks_url': 'https://api.github.com/repos/google/gson/forks',
#   'keys_url': 'https://api.github.com/repos/google/gson/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/google/gson/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/google/gson/teams',
#   'hooks_url': 'https://api.github.com/repos/google/gson/hooks',
#   'issue_events_url': 'https://api.github.com/repos/google/gson/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/google/gson/events',
#   'assignees_url': 'https://api.github.com/repos/google/gson/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/google/gson/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/google/gson/tags',
#   'blobs_url': 'https://api.github.com/repos/google/gson/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/google/gson/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/google/gson/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/google/gson/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/google/gson/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/google/gson/languages',
#   'stargazers_url': 'https://api.github.com/repos/google/gson/stargazers',
#   'contributors_url': 'https://api.github.com/repos/google/gson/contributors',
#   'subscribers_url': 'https://api.github.com/repos/google/gson/subscribers',
#   'subscription_url': 'https://api.github.com/repos/google/gson/subscription',
#   'commits_url': 'https://api.github.com/repos/google/gson/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/google/gson/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/google/gson/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/google/gson/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/google/gson/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/google/gson/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/google/gson/merges',
#   'archive_url': 'https://api.github.com/repos/google/gson/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/google/gson/downloads',
#   'issues_url': 'https://api.github.com/repos/google/gson/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/google/gson/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/google/gson/milestones{/number}',
# ...
#    'gists_url': 'https://api.github.com/users/google/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/google/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/google/subscriptions',
#    'organizations_url': 'https://api.github.com/users/google/orgs',
#    'repos_url': 'https://api.github.com/users/google/repos',
#    'events_url': 'https://api.github.com/users/google/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/google/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/google/grr',
#   'description': 'GRR Rapid Response: remote live forensics for incident response',
#   'fork': False,
#   'url': 'https://api.github.com/repos/google/grr',
#   'forks_url': 'https://api.github.com/repos/google/grr/forks',
#   'keys_url': 'https://api.github.com/repos/google/grr/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/google/grr/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/google/grr/teams',
#   'hooks_url': 'https://api.github.com/repos/google/grr/hooks',
#   'issue_events_url': 'https://api.github.com/repos/google/grr/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/google/grr/events',
#   'assignees_url': 'https://api.github.com/repos/google/grr/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/google/grr/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/google/grr/tags',
#   'blobs_url': 'https://api.github.com/repos/google/grr/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/google/grr/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/google/grr/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/google/grr/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/google/grr/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/google/grr/languages',
#   'stargazers_url': 'https://api.github.com/repos/google/grr/stargazers',
#   'contributors_url': 'https://api.github.com/repos/google/grr/contributors',
#   'subscribers_url': 'https://api.github.com/repos/google/grr/subscribers',
#   'subscription_url': 'https://api.github.com/repos/google/grr/subscription',
#   'commits_url': 'https://api.github.com/repos/google/grr/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/google/grr/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/google/grr/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/google/grr/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/google/grr/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/google/grr/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/google/grr/merges',
#   'archive_url': 'https://api.github.com/repos/google/grr/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/google/grr/downloads',
#   'issues_url': 'https://api.github.com/repos/google/grr/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/google/grr/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/google/grr/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/google/grr/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/google/grr/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/google/grr/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/google/grr/deployments',
#   'created_at': '2013-12-04T00:17:53Z',
#   'updated_at': '2021-05-04T11:15:47Z',
#   'pushed_at': '2021-05-04T11:15:43Z',
#   'git_url': 'git://github.com/google/grr.git',
#   'ssh_url': 'git@github.com:google/grr.git',
#   'clone_url': 'https://github.com/google/grr.git',
#   'svn_url': 'https://github.com/google/grr',
#   'homepage': 'https://grr-doc.readthedocs.io/',
#   'size': 161100,
#   'stargazers_count': 3782,
#   'watchers_count': 3782,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': True,
#   'forks_count': 687,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 133,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'forks': 687,
#   'open_issues': 133,
#   'watchers': 3782,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True},
#   'score': 1.0},
#  {'id': 16316451,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNjMxNjQ1MQ==',
#   'name': 'google-cloud-python',
#   'full_name': 'googleapis/google-cloud-python',
#   'private': False,
#   'owner': {'login': 'googleapis',
#    'id': 16785467,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE2Nzg1NDY3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16785467?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/googleapis',
#    'html_url': 'https://github.com/googleapis',
#    'followers_url': 'https://api.github.com/users/googleapis/followers',
#    'following_url': 'https://api.github.com/users/googleapis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/googleapis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/googleapis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/googleapis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/googleapis/orgs',
#    'repos_url': 'https://api.github.com/users/googleapis/repos',
#    'events_url': 'https://api.github.com/users/googleapis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/googleapis/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/googleapis/google-cloud-python',
#   'description': 'Google Cloud Client Library for Python',
#   'fork': False,
#   'url': 'https://api.github.com/repos/googleapis/google-cloud-python',
#   'forks_url': 'https://api.github.com/repos/googleapis/google-cloud-python/forks',
#   'keys_url': 'https://api.github.com/repos/googleapis/google-cloud-python/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/googleapis/google-cloud-python/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/googleapis/google-cloud-python/teams',
#   'hooks_url': 'https://api.github.com/repos/googleapis/google-cloud-python/hooks',
#   'issue_events_url': 'https://api.github.com/repos/googleapis/google-cloud-python/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/googleapis/google-cloud-python/events',
#   'assignees_url': 'https://api.github.com/repos/googleapis/google-cloud-python/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/googleapis/google-cloud-python/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/googleapis/google-cloud-python/tags',
#   'blobs_url': 'https://api.github.com/repos/googleapis/google-cloud-python/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/googleapis/google-cloud-python/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/googleapis/google-cloud-python/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/googleapis/google-cloud-python/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/googleapis/google-cloud-python/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/googleapis/google-cloud-python/languages',
#   'stargazers_url': 'https://api.github.com/repos/googleapis/google-cloud-python/stargazers',
#   'contributors_url': 'https://api.github.com/repos/googleapis/google-cloud-python/contributors',
#   'subscribers_url': 'https://api.github.com/repos/googleapis/google-cloud-python/subscribers',
#   'subscription_url': 'https://api.github.com/repos/googleapis/google-cloud-python/subscription',
#   'commits_url': 'https://api.github.com/repos/googleapis/google-cloud-python/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/googleapis/google-cloud-python/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/googleapis/google-cloud-python/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/googleapis/google-cloud-python/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/googleapis/google-cloud-python/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/googleapis/google-cloud-python/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/googleapis/google-cloud-python/merges',
#   'archive_url': 'https://api.github.com/repos/googleapis/google-cloud-python/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/googleapis/google-cloud-python/downloads',
#   'issues_url': 'https://api.github.com/repos/googleapis/google-cloud-python/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/googleapis/google-cloud-python/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/googleapis/google-cloud-python/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/googleapis/google-cloud-python/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/googleapis/google-cloud-python/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/googleapis/google-cloud-python/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/googleapis/google-cloud-python/deployments',
#   'created_at': '2014-01-28T15:51:47Z',
#   'updated_at': '2021-05-06T13:17:38Z',
#   'pushed_at': '2021-04-28T14:50:34Z',
#   'git_url': 'git://github.com/googleapis/google-cloud-python.git',
#   'ssh_url': 'git@github.com:googleapis/google-cloud-python.git',
#   'clone_url': 'https://github.com/googleapis/google-cloud-python.git',
#   'svn_url': 'https://github.com/googleapis/google-cloud-python',
#   'homepage': 'https://googleapis.github.io/google-cloud-python/',
#   'size': 1781326,
#   'stargazers_count': 3557,
#   'watchers_count': 3557,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': True,
#   'forks_count': 1355,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 25,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'forks': 1355,
#   'open_issues': 25,
#   'watchers': 3557,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True},
#   'score': 1.0},
#  {'id': 44087204,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0NDA4NzIwNA==',
#   'name': 'syzkaller',
#   'full_name': 'google/syzkaller',
#   'private': False,
#   'owner': {'login': 'google',
#    'id': 1342004,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEzNDIwMDQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1342004?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/google',
#    'html_url': 'https://github.com/google',
#    'followers_url': 'https://api.github.com/users/google/followers',
#    'following_url': 'https://api.github.com/users/google/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/google/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/google/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/google/subscriptions',
#    'organizations_url': 'https://api.github.com/users/google/orgs',
#    'repos_url': 'https://api.github.com/users/google/repos',
#    'events_url': 'https://api.github.com/users/google/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/google/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/google/syzkaller',
#   'description': 'syzkaller is an unsupervised coverage-guided kernel fuzzer',
#   'fork': False,
#   'url': 'https://api.github.com/repos/google/syzkaller',
#   'forks_url': 'https://api.github.com/repos/google/syzkaller/forks',
#   'keys_url': 'https://api.github.com/repos/google/syzkaller/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/google/syzkaller/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/google/syzkaller/teams',
#   'hooks_url': 'https://api.github.com/repos/google/syzkaller/hooks',
#   'issue_events_url': 'https://api.github.com/repos/google/syzkaller/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/google/syzkaller/events',
#   'assignees_url': 'https://api.github.com/repos/google/syzkaller/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/google/syzkaller/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/google/syzkaller/tags',
#   'blobs_url': 'https://api.github.com/repos/google/syzkaller/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/google/syzkaller/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/google/syzkaller/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/google/syzkaller/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/google/syzkaller/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/google/syzkaller/languages',
#   'stargazers_url': 'https://api.github.com/repos/google/syzkaller/stargazers',
#   'contributors_url': 'https://api.github.com/repos/google/syzkaller/contributors',
#   'subscribers_url': 'https://api.github.com/repos/google/syzkaller/subscribers',
#   'subscription_url': 'https://api.github.com/repos/google/syzkaller/subscription',
#   'commits_url': 'https://api.github.com/repos/google/syzkaller/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/google/syzkaller/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/google/syzkaller/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/google/syzkaller/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/google/syzkaller/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/google/syzkaller/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/google/syzkaller/merges',
#   'archive_url': 'https://api.github.com/repos/google/syzkaller/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/google/syzkaller/downloads',
#   'issues_url': 'https://api.github.com/repos/google/syzkaller/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/google/syzkaller/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/google/syzkaller/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/google/syzkaller/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/google/syzkaller/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/google/syzkaller/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/google/syzkaller/deployments',
#   'created_at': '2015-10-12T06:05:05Z',
#   'updated_at': '2021-05-06T14:49:00Z',
#   'pushed_at': '2021-05-06T14:48:55Z',
#   'git_url': 'git://github.com/google/syzkaller.git',
#   'ssh_url': 'git@github.com:google/syzkaller.git',
#   'clone_url': 'https://github.com/google/syzkaller.git',
#   'svn_url': 'https://github.com/google/syzkaller',
#   'homepage': '',
#   'size': 141449,
#   'stargazers_count': 3499,
#   'watchers_count': 3499,
#   'language': 'Go',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': False,
#   'has_wiki': False,
#   'has_pages': False,
#   'forks_count': 810,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 179,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'forks': 810,
#   'open_issues': 179,
#   'watchers': 3499,
#   'default_branch': 'master',
#   'permissions': {'admin': False, 'push': False, 'pull': True},
#   'score': 1.0}]

# %%
headers = az.headers
endpoint = "https://api.github.com/search/repositories"
query = ""
type = "users"
sort = "stars"
per_page = 100
order = "desc"
page = 1
#Make the request
response = requests.get(f"{endpoint}?q={query}&type={type}&sort={sort}&per_page={per_page}&order={order}&page={page}", headers=headers)
payload = response.json()
payload['items']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-3ec8b8d6c873> in <module>
#       9 response = requests.get(f"{endpoint}?q={query}&sort={sort}&per_page={per_page}&order={order}&page={page}", headers=headers)
#      10 payload = response.json()
# ---> 11 payload['items']
#
# KeyError: 'items'

# %%
def get_githubpgs():
    """
    This function will create a list of all the url pages in the google repos section
    """
    urls = []
    for i in range(1,68):
        
        url = f'https://https://github.com/google?page={i}'
        urls.append(url)
    return urls

# %%
pages = get_githubpgs()

# %%
pages
# Out:
# ['https://https://github.com/google?page=1',
#  'https://https://github.com/google?page=2',
#  'https://https://github.com/google?page=3',
#  'https://https://github.com/google?page=4',
#  'https://https://github.com/google?page=5',
#  'https://https://github.com/google?page=6',
#  'https://https://github.com/google?page=7',
#  'https://https://github.com/google?page=8',
#  'https://https://github.com/google?page=9',
#  'https://https://github.com/google?page=10',
#  'https://https://github.com/google?page=11',
#  'https://https://github.com/google?page=12',
#  'https://https://github.com/google?page=13',
#  'https://https://github.com/google?page=14',
#  'https://https://github.com/google?page=15',
#  'https://https://github.com/google?page=16',
#  'https://https://github.com/google?page=17',
#  'https://https://github.com/google?page=18',
#  'https://https://github.com/google?page=19',
#  'https://https://github.com/google?page=20',
#  'https://https://github.com/google?page=21',
#  'https://https://github.com/google?page=22',
#  'https://https://github.com/google?page=23',
#  'https://https://github.com/google?page=24',
#  'https://https://github.com/google?page=25',
#  'https://https://github.com/google?page=26',
#  'https://https://github.com/google?page=27',
#  'https://https://github.com/google?page=28',
#  'https://https://github.com/google?page=29',
#  'https://https://github.com/google?page=30',
#  'https://https://github.com/google?page=31',
#  'https://https://github.com/google?page=32',
#  'https://https://github.com/google?page=33',
#  'https://https://github.com/google?page=34',
#  'https://https://github.com/google?page=35',
#  'https://https://github.com/google?page=36',
#  'https://https://github.com/google?page=37',
#  'https://https://github.com/google?page=38',
#  'https://https://github.com/google?page=39',
#  'https://https://github.com/google?page=40',
#  'https://https://github.com/google?page=41',
#  'https://https://github.com/google?page=42',
#  'https://https://github.com/google?page=43',
#  'https://https://github.com/google?page=44',
#  'https://https://github.com/google?page=45',
#  'https://https://github.com/google?page=46',
#  'https://https://github.com/google?page=47',
#  'https://https://github.com/google?page=48',
#  'https://https://github.com/google?page=49',
#  'https://https://github.com/google?page=50',
#  'https://https://github.com/google?page=51',
#  'https://https://github.com/google?page=52',
#  'https://https://github.com/google?page=53',
#  'https://https://github.com/google?page=54',
#  'https://https://github.com/google?page=55',
#  'https://https://github.com/google?page=56',
#  'https://https://github.com/google?page=57',
#  'https://https://github.com/google?page=58',
#  'https://https://github.com/google?page=59',
#  'https://https://github.com/google?page=60',
#  'https://https://github.com/google?page=61',
#  'https://https://github.com/google?page=62',
#  'https://https://github.com/google?page=63',
#  'https://https://github.com/google?page=64',
#  'https://https://github.com/google?page=65',
#  'https://https://github.com/google?page=66',
#  'https://https://github.com/google?page=67']

# %%
url = 'https://github.com/google?page=1'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
response = requests.get(url, headers=headers)

html = response.text
soup = BeautifulSoup(html)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-b1fd4fa68a3c095c7e600e3b8888b621.css" integrity="sha512-sf1Ppoo8CVx+YA47iIi2IUMYtjH17Errad0dPA+lo7DVd6VW1Mdy+TBcpD06Z6FN8MKI7TH5fpYU33+DhP25kg==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/behaviors-d8b569a974bdcfe2ab9472d9cccb2f0b.css" integrity="sha512-2LVpqXS9z+KrlHLZzMsvC6qnP0II4eScPyK8KYx6GCAQ/flbvb6qMDt0Bpm8/baIc9rCILWGRclwA2qLY6yNQg==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-379d10eb1975d43d70ea634366452105.css" integrity="sha512-N50Q6xl11D1w6mNDZkUhBVhZuxYaKWF+5v9HffuWBlZC5L5xIPlIASbSgCw5DofX5wj4yulh6hhZKapeuvjc7A==" media="all" rel="stylesheet"/>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-CzeY4A6TiG4fGZSWZU8FxmzFFmcQFoPpArF0hkH0/J/S7UL4eed/LKEXMQXfTwiG5yEJBI+9BdKG8KQJNbhcIQ==" src="https://github.githubassets.com/assets/environment-0b3798e0.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-ymgKJHPO04ImkRAtKz2qN2gw7VG4Uo6NI9usvATL1F8VslBSPv/JKd+GC7mwDXfcwgtsofN7TW5xsyB0uTiDDg==" src="https://github.githubassets.com/assets/chunk-frameworks-ca680a24.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-yakjM7b2IGtqO51Ujy99D+xFW4sBud72051Q569rNIrcKwPuO7bjJfmfBVvUGTQlvn9PHHxmlwcGC2dx3eKKbA==" src="https://github.githubassets.com/assets/chunk-vendor-c9a92333.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-7sHLSdErxvBmD4WOjRh+BgPpVz950bby/QtjdCdke+Ibo81kWcVwPKaNeNS5hkY4rnoITK9x5Yx4Jl0ph2RMcg==" src="https://github.githubassets.com/assets/behaviors-eec1cb49.js" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-animate-on-scroll.js" data-src="https://github.githubassets.com/assets/chunk-animate-on-scroll-b63b8d41.js" defer="defer" integrity="sha512-tjuNQcwhEIXGvVIG4XM/Aj4z+Od+NBRkbgWNwEMjGL3nsnAmdoBdbzsn/WTvl3hk+TPt1D0BvBLHLBPgiwvT2w==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-codemirror.js" data-src="https://github.githubassets.com/assets/chunk-codemirror-f81284b4.js" defer="defer" integrity="sha512-+BKEtK9JkmJ52jKSoX6+SBrGV6kJxB8J/iAPkFQ/oeq8YekNcz7IZlJgM5Tddyx1RrkL3+sdG0tAy3YuFbYqfA==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-color-modes.js" data-src="https://github.githubassets.com/assets/chunk-color-modes-10a3afa8.js" defer="defer" integrity="sha512-EKOvqJ9uTatAt87WxU+OSS4mi7gMUszFbGo4aPErQkjpWLXnrPSeZvK5ngU8OYoIoiVOq+v8dA3C6MF/z2d/kA==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-contributions-spider-graph.js" data-src="https://github.githubassets.com/assets/chunk-contributions-spider-graph-ce46194a.js" defer="defer" integrity="sha512-zkYZSjUFqSifB+Lt76jclFMrfqpcPqevT801RZcoBNCZHRTBKcFrW9OyJoPOzKFv+fZVDRnqdqGsuIv5KOIgZg==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-drag-drop.js" data-src="https://github.githubassets.com/assets/chunk-drag-drop-ea3fe848.js" defer="defer" integrity="sha512-6j/oSF+kbW+yetNPvI684VzAu9pzug6Vj2h+3u1LdCuRhR4jnuiHZfeQKls3nxcT/S3H+oIt7FtigE/aeoj+gg==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-edit-hook-secret-element.js" data-src="https://github.githubassets.com/assets/chunk-edit-hook-secret-element-55249df9.js" defer="defer" integrity="sha512-VSSd+Yzi2iMS+pibY6hD/WdypxAEdob5F2RMKxuKcAHS2EpFYJPeTXoVxt0NXg03tfj2dka2mEtHS+vjpYSaDw==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-edit.js" data-src="https://github.githubassets.com/assets/chunk-edit-37ece2a8.js" defer="defer" integrity="sha512-N+ziqJjVMfWiqeVHdayDHpNRlG5HsF+cgV+pFnMDoTJuvBzgw+ndsepe4NcKAxIS3WMvzMaQcYmd2vrIaoAJVg==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-emoji-picker-element.js" data-src="https://github.githubassets.com/assets/chunk-emoji-picker-element-6a2a8c20.js" defer="defer" integrity="sha512-aiqMIGGZGo8AQMjcoImKPMTsZVVRl6htCSY7BpRmpGPG/AF+Wq+P/Oj/dthWQOIk9cCNMPEas7O2zAR6oqn0tA==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-filter-input.js" data-src="https://github.githubassets.com/assets/chunk-filter-input-ee8f16a1.js" defer="defer" integrity="sha512-7o8WoXZcP71e0YBbF1az3Rj9iGr3Irk3kb7Yq1/ZQETySta8pQLfupQJ7yiswg+sN1HTqszDMbp1vcPHFgp7gw==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-insights-graph.js" data-src="https://github.githubassets.com/assets/chunk-insights-graph-5f0b9074.js" defer="defer" integrity="sha512-XwuQdORq1W9Z+a/i72pH+NfR1rhwlGdxIlaIBbTciscGc/+McxMNLixGBp8e6Td4W1zzHvQ1Jyryl5gUfEr76g==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-invitations.js" data-src="https://github.githubassets.com/assets/chunk-invitations-63e55517.js" defer="defer" integrity="sha512-Y+VVFzGHo9J5bf4Mrn+RGrh1+IExdybA3C1QqPha3UwkV9RZ75jZgV4DsujViAF0iT9OrLYYHvPk9V6QiXjp3g==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-jump-to.js" data-src="https://github.githubassets.com/assets/chunk-jump-to-98c3af11.js" defer="defer" integrity="sha512-mMOvER8Uml4WMYbXv8BaahVq9eF1v5Hu7M9/3oPlOFPmTJGH+TmvcRPt8fddj86urb+Ri+vlqotFspA/4STDsQ==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-notification-list-focus.js" data-src="https://github.githubassets.com/assets/chunk-notification-list-focus-b2ea5993.js" defer="defer" integrity="sha512-supZkxo+OPYLNtLXxI+e1dkCqVySu4FOWX1fiVVFs2ZggygppNsEz4F9wVp4YtH2TjFsZW8r/75uDUhPneO2sA==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-profile-pins-element.js" data-src="https://github.githubassets.com/assets/chunk-profile-pins-element-99ad0e3b.js" defer="defer" integrity="sha512-ma0OOy3nj0c1cqBx0BkcmIFsLqcSZ+MIukQxyEFM/OWTzZpG+QMgOoWPAHZz43M6fyjAUG1jH6c/6LPiiKPCyw==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-ref-selector.js" data-src="https://github.githubassets.com/assets/chunk-ref-selector-ce1fad61.js" defer="defer" integrity="sha512-zh+tYYvd4W00us1O4PkhmKsl/CzInIyrdoMqV2xqC7XPu06UEHfEMJfOiwidJ5f80SwrdGWogWFuJzLHwRbRgA==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-responsive-underlinenav.js" data-src="https://github.githubassets.com/assets/chunk-responsive-underlinenav-6628bda1.js" defer="defer" integrity="sha512-Zii9oRdZ6q2QDNjL5A+me7jwJjMLvs1NiQNHmajUZnn4t9shcBDb4F8l/PQZW26eYfe5065oM7lIOSmbMinA7Q==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-runner-groups.js" data-src="https://github.githubassets.com/assets/chunk-runner-groups-f56357b4.js" defer="defer" integrity="sha512-9WNXtB07IyWypiPmkuucspwog4mme9q5GKGMSgd7FI0DPimmg/pEw+aaAofFV1vuWMt9I8H5QpsVtlbHGg1YBA==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-sortable-behavior.js" data-src="https://github.githubassets.com/assets/chunk-sortable-behavior-7c8abd32.js" defer="defer" integrity="sha512-fIq9Mn7jY/bHQXnsmh+VejpDnaO+d/FDxsp+4CuZtdNLrLuO+dQCjh+m6Yd8GCYD2Cy6DWbCEyM+mH2dkB2H9A==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-toast.js" data-src="https://github.githubassets.com/assets/chunk-toast-58af155f.js" defer="defer" integrity="sha512-WK8VXw3lfUQ/VRW0zlgKPhcMUqH0uTnB/KzePUPdZhCm/HpxfXXHKTGvj5C0Oex7+zbIM2ECzULbtTCT4ug3yg==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-tweetsodium.js" data-src="https://github.githubassets.com/assets/chunk-tweetsodium-be01c912.js" defer="defer" integrity="sha512-vgHJEmEJxNmHucGbVY8bEUoOYo5/ZwpQ69rU8Dld89daWJ54uad9lNptxq32F8pnbHhdngw9lohNEbMbjmj5AQ==" type="application/javascript"></script>
# <script crossorigin="anonymous" data-module-id="./chunk-user-status-submit.js" data-src="https://github.githubassets.com/assets/chunk-user-status-submit-692c5f4c.js" defer="defer" integrity="sha512-aSxfTHAZj9wv7n08DxgAKkNg7jhiTo4yKKbDqLGxcDxUk/al571Y2ZSsOmLJ0Vh8cuAL8tW+JgX1t0JeKfyfaA==" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-uCQCwCYVwLRGv2mWmK++56P6fr27WqWzW8XZTTV6BimDhoOpwWa9HE9pFSDIEJN3KJ6Bv9klVCd+hOLTmexa0A==" src="https://github.githubassets.com/assets/profile-b82402c0.js" type="application/javascript"></script>
# <meta content="width=device-width" name="viewport"/>
# <meta content="noindex, follow" name="robots"/>
# <title>Google · GitHub</title>
# <meta content="Google ❤️ Open Source. Google has 2011 repositories available. Follow their code on GitHub." name="description"/>
# <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
# <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
# <meta content="1401488693436528" property="fb:app_id"/>
# <meta content="app-id=1477376905" name="apple-itunes-app"/>
# <meta content="https://avatars.githubusercontent.com/u/1342004?s=280&amp;v=4" name="twitter:image:src"/><meta content="@github" name="twitter:site"/><meta content="summary_large_image" name="twitter:card"/><meta content="Google" name="twitter:title"/><meta content="Google ❤️ Open Source. Google has 2011 repositories available. Follow their code on GitHub." name="twitter:description"/>
# <meta content="https://avatars.githubusercontent.com/u/1342004?s=280&amp;v=4" property="og:image"/><meta content="Google ❤️ Open Source. Google has 2011 repositories available. Follow their code on GitHub." property="og:image:alt"/><meta content="GitHub" property="og:site_name"/><meta content="profile" property="og:type"/><meta content="Google" property="og:title"/><meta content="https://github.com/google" property="og:url"/><meta content="Google ❤️ Open Source. Google has 2011 repositories available. Follow their code on GitHub." property="og:description"/><meta content="google" property="profile:username"/>
# <link href="https://github.githubassets.com/" rel="assets"/>
# <meta content="E672:7E88:59192:D9EA9:609476A5" data-pjax-transient="true" name="request-id"/><meta content="9a292cbd6f8fef1f89904b4cab5883fea7a2d07e6ecc7ef712b464c7cd590f6e" data-pjax-transient="true" name="html-safe-nonce"/><meta content="eyJyZWZlcnJlciI6IiIsInJlcXVlc3RfaWQiOiJFNjcyOjdFODg6NTkxOTI6RDlFQTk6NjA5NDc2QTUiLCJ2aXNpdG9yX2lkIjoiNDk2ODMxNDY0Mzc0MTQzOTY1MyIsInJlZ2lvbl9lZGdlIjoiaWFkIiwicmVnaW9uX3JlbmRlciI6ImlhZCJ9" data-pjax-transient="true" name="visitor-payload"/><meta content="a4b473cdd5315f4016b4b007cb86b28e13015fde0983b92f39c1a4342982a256" data-pjax-transient="true" name="visitor-hmac"/>
# <meta content="organization:1342004" data-pjax-transient="" name="hovercard-subject-tag"/>
# <meta content="" data-pjax-transient="true" name="github-keyboard-shortcuts"/>
# <meta data-pjax-transient="" name="selected-link" value="/google"/>
# <meta content="c1kuD-K2HIVF635lypcsWPoD4kilo5-jA_wBFyT4uMY" name="google-site-verification"/>
# <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
# <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
# <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
# <meta content="collector.githubapp.com" name="octolytics-host"/><meta content="github" name="octolytics-app-id"/><meta content="https://collector.githubapp.com/github-external/browser_event" name="octolytics-event-url"/>
# <meta content="/&lt;org-login&gt;" data-pjax-transient="true" name="analytics-location"/>
# <meta content="github.com" name="hostname"/>
# <meta content="" name="user-login"/>
# <meta content="github.com" name="expected-hostname"/>
# <meta content="MARKETPLACE_PENDING_INSTALLATIONS,AUTOCOMPLETE_EMOJIS_IN_MARKDOWN_EDITOR,ACTIONS_CONCURRENCY_UI" name="enabled-features"/>
# <meta content="18a6e3871d9a6f81f94197b1aba425180cdaa10e4861c8c9af46349afc753cad" http-equiv="x-pjax-version"/>
# <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
# <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
# <meta content="https://api.github.com/_private/browser/optimizely_client/errors" name="browser-optimizely-client-errors-url"/>
# <link color="#000000" href="https://github.githubassets.com/pinned-octocat.svg" rel="mask-icon"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.png" rel="alternate icon" type="image/png"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="#1e2327" name="theme-color"/>
# <meta content="light dark" name="color-scheme"/>
# <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
# <meta content="ko" name="enabled-homepage-translation-languages"/>
# </head>
# <body class="logged-out env-production page-responsive" style="word-wrap: break-word;">
# <div class="position-relative js-header-wrapper">
# <a class="px-2 py-4 color-bg-info-inverse color-text-white show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>
# <span class="progress-pjax-loader width-full js-pjax-loader-bar Progress position-fixed">
# <span class="Progress-item progress-pjax-loader-bar" style="background-color: #79b8ff;width: 0%;"></span>
# </span>
# <header class="Header-old header-logged-out js-details-container Details position-relative f4 py-2" role="banner">
# <div class="container-lg d-lg-flex flex-items-center p-responsive">
# <div class="d-flex flex-justify-between flex-items-center">
# <a aria-label="Homepage" class="mr-4" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github color-text-white" height="32" version="1.1" viewbox="0 0 16 16" width="32"><path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path></svg>
# </a>
# <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">
# <a class="Header-link" href="/google">google</a>
# </div>
# <div class="d-flex flex-items-center">
# <nux-signup-candidates data-action="loaded:nux-signup-candidates#determineSignupAction" data-attribute-name="href" data-candidate-url="/join_next?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2F%3Corg-login%3E&amp;source=header">
# <a class="d-inline-block d-lg-none f5 color-text-white no-underline border color-border-tertiary rounded-2 px-2 py-1 mr-3 mr-sm-5" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/google?page=1","user_id":null}}' data-hydro-click-hmac="06a4b59e355dbc2d5af0cb9c46b4a7ac9f10bbc583c4ba15e73436cce84e3593" data-target="nux-signup-candidates.signupAction" href="/join?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2F%3Corg-login%3E&amp;source=header">
#                   Sign up
#                 </a>
# </nux-signup-candidates>
# <button aria-expanded="false" aria-label="Toggle navigation" class="btn-link d-lg-none mt-1 js-details-target" type="button">
# <svg aria-hidden="true" class="octicon octicon-three-bars color-text-white" height="24" version="1.1" viewbox="0 0 16 16" width="24"><path d="M1 2.75A.75.75 0 011.75 2h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 2.75zm0 5A.75.75 0 011.75 7h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 7.75zM1.75 12a.75.75 0 100 1.5h12.5a.75.75 0 100-1.5H1.75z" fill-rule="evenodd"></path></svg>
# </button>
# </div>
# </div>
# <div class="HeaderMenu HeaderMenu--logged-out position-fixed top-0 right-0 bottom-0 height-fit position-lg-relative d-lg-flex flex-justify-between flex-items-center flex-auto">
# <div class="d-flex d-lg-none flex-justify-end border-bottom color-bg-secondary p-3">
# <button aria-expanded="false" aria-label="Toggle navigation" class="btn-link js-details-target" type="button">
# <svg aria-hidden="true" class="octicon octicon-x color-text-secondary" height="24" version="1.1" viewbox="0 0 24 24" width="24"><path d="M5.72 5.72a.75.75 0 011.06 0L12 10.94l5.22-5.22a.75.75 0 111.06 1.06L13.06 12l5.22 5.22a.75.75 0 11-1.06 1.06L12 13.06l-5.22 5.22a.75.75 0 01-1.06-1.06L10.94 12 5.72 6.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path></svg>
# </button>
# </div>
# <nav aria-label="Global" class="mt-0 px-3 px-lg-0 mb-5 mb-lg-0">
# <ul class="d-lg-flex list-style-none">
# <li class="d-block d-lg-flex flex-lg-nowrap flex-lg-items-center border-bottom border-lg-bottom-0 mr-0 mr-lg-3 edge-item-fix position-relative flex-wrap flex-justify-between d-flex flex-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#                     Why GitHub?
#                     <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0px" xml:space="preserve" y="0px">
# <path d="M1,1l6.2,6L13,1"></path>
# </svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <a class="py-2 lh-condensed-ultra d-block Link--primary no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Features" href="/features">Features <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a>
# <ul class="list-style-none f5 pb-3">
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" href="/mobile">Mobile <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" href="/features/actions">Actions <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" href="/features/codespaces">Codespaces <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" href="/features/packages">Packages <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" href="/features/security">Security <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" href="/features/code-review/">Code review <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" href="/features/project-management/">Project management <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" href="/features/integrations">Integrations <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# </ul>
# <ul class="list-style-none mb-0 border-lg-top pt-lg-3">
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block no-underline Link--primary no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Sponsors" href="/sponsors">GitHub Sponsors <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block no-underline Link--primary no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Customer stories" href="/customer-stories">Customer stories<span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# </ul>
# </div>
# </details>
# </li>
# <li class="border-bottom border-lg-bottom-0 mr-0 mr-lg-3">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-ga-click="(Logged out) Header, go to Team" href="/team">Team</a>
# </li>
# <li class="border-bottom border-lg-bottom-0 mr-0 mr-lg-3">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-ga-click="(Logged out) Header, go to Enterprise" href="/enterprise">Enterprise</a>
# </li>
# <li class="d-block d-lg-flex flex-lg-nowrap flex-lg-items-center border-bottom border-lg-bottom-0 mr-0 mr-lg-3 edge-item-fix position-relative flex-wrap flex-justify-between d-flex flex-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#                     Explore
#                     <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0px" xml:space="preserve" y="0px">
# <path d="M1,1l6.2,6L13,1"></path>
# </svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 pt-2 pb-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none mb-3">
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--primary no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Explore" href="/explore">Explore GitHub <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# </ul>
# <h4 class="color-text-tertiary text-normal text-mono f5 mb-2 border-lg-top pt-lg-3">Learn and contribute</h4>
# <ul class="list-style-none mb-3">
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Topics" href="/topics">Topics <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Collections" href="/collections">Collections <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Trending" href="/trending">Trending <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Learning lab" href="https://lab.github.com/">Learning Lab <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Open source guides" href="https://opensource.guide">Open source guides <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# </ul>
# <h4 class="color-text-tertiary text-normal text-mono f5 mb-2 border-lg-top pt-lg-3">Connect with others</h4>
# <ul class="list-style-none mb-0">
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" href="https://github.com/readme">The ReadME Project <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Events" href="https://github.com/events">Events <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Community forum" href="https://github.community">Community forum <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" data-ga-click="(Logged out) Header, go to GitHub Education" href="https://education.github.com">GitHub Education <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 pb-0 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" data-ga-click="(Logged out) Header, go to GitHub Stars Program" href="https://stars.github.com">GitHub Stars program <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# </ul>
# </div>
# </details>
# </li>
# <li class="border-bottom border-lg-bottom-0 mr-0 mr-lg-3">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-ga-click="(Logged out) Header, go to Marketplace" href="/marketplace">Marketplace</a>
# </li>
# <li class="d-block d-lg-flex flex-lg-nowrap flex-lg-items-center border-bottom border-lg-bottom-0 mr-0 mr-lg-3 edge-item-fix position-relative flex-wrap flex-justify-between d-flex flex-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#                     Pricing
#                     <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0px" xml:space="preserve" y="0px">
# <path d="M1,1l6.2,6L13,1"></path>
# </svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 pt-2 pb-4 mt-0 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <a class="pb-2 lh-condensed-ultra d-block Link--primary no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Pricing" href="/pricing">Plans <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a>
# <ul class="list-style-none mb-3">
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Compare plans" href="/pricing#feature-comparison">Compare plans <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# <li class="edge-item-fix"><a class="py-2 lh-condensed-ultra d-block Link--secondary no-underline f5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Contact Sales" href="https://enterprise.github.com/contact">Contact Sales <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# </ul>
# <ul class="list-style-none mb-0 border-lg-top pt-lg-3">
# <li class="edge-item-fix"><a class="py-2 pb-0 lh-condensed-ultra d-block no-underline Link--primary no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Education" href="https://education.github.com">Education <span class="Bump-link-symbol float-right text-normal color-text-tertiary pr-3">→</span></a></li>
# </ul>
# </div>
# </details>
# </li>
# </ul>
# </nav>
# <div class="d-lg-flex flex-items-center px-3 px-lg-0 text-center text-lg-left">
# <div class="d-lg-flex min-width-0 mb-3 mb-lg-0">
# <div aria-expanded="false" aria-haspopup="listbox" aria-label="Search or jump to" aria-owns="jump-to-results" class="header-search flex-auto js-site-search position-relative flex-self-stretch flex-md-self-auto mb-3 mb-md-0 mr-0 mr-md-3 scoped-search site-scoped-search js-jump-to" role="combobox">
# <div class="position-relative">
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="/orgs/google/search" aria-label="Site" class="js-site-search-form" data-scope-id="1342004" data-scope-type="Organization" data-scoped-search-url="/orgs/google/search" data-unscoped-search-url="/search" method="get" role="search">
# <label class="form-control input-sm header-search-wrapper p-0 js-chromeless-input-container header-search-wrapper-jump-to position-relative d-flex flex-justify-between flex-items-center">
# <input aria-autocomplete="list" aria-controls="jump-to-results" aria-label="Search" autocapitalize="off" autocomplete="off" class="form-control input-sm header-search-input jump-to-field js-jump-to-field js-site-search-focus js-site-search-field is-clearable" data-hotkey="s,/" data-jump-to-suggestions-path="/_graphql/GetSuggestedNavigationDestinations" data-scoped-placeholder="Search" data-unscoped-placeholder="Search GitHub" name="q" placeholder="Search" spellcheck="false" type="text" value=""/>
# <input class="js-data-jump-to-suggestions-path-csrf" data-csrf="true" type="hidden" value="Abn5lFeFUzeHvAIg3mz3iQpyhyiI2vN3bzMRWQxOo095K9MlH/wOpzHOSwee+9gce60oYq85Fx0nRR4/OBC6qg=="/>
# <input class="js-site-search-type-field" name="type" type="hidden"/>
# <img alt="" class="mr-2 header-search-key-slash" src="https://github.githubassets.com/images/search-key-slash.svg"/>
# <div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
# <ul class="d-none js-jump-to-suggestions-template-container">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="suggestion" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16"><path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16"><path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16"><path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path></svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-1 flex-shrink-0 color-bg-tertiary px-1 color-text-tertiary ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this organization" class="js-jump-to-badge-search-text-default d-none">
#         In this organization
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-1 flex-shrink-0 color-bg-tertiary px-1 color-text-tertiary ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="d-none js-jump-to-no-results-template-container">
# <li class="d-flex flex-justify-center flex-items-center f5 d-none js-jump-to-suggestion p-2">
# <span class="color-text-secondary">No suggested jump to results</span>
# </li>
# </ul>
# <ul class="p-0 m-0 js-navigation-container jump-to-suggestions-results-container js-jump-to-suggestions-results-container" id="jump-to-results" role="listbox">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16"><path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16"><path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16"><path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path></svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-1 flex-shrink-0 color-bg-tertiary px-1 color-text-tertiary ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this organization" class="js-jump-to-badge-search-text-default d-none">
#         In this organization
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-1 flex-shrink-0 color-bg-tertiary px-1 color-text-tertiary ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-owner-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="owner_scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16"><path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16"><path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16"><path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path></svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-1 flex-shrink-0 color-bg-tertiary px-1 color-text-tertiary ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-1 flex-shrink-0 color-bg-tertiary px-1 color-text-tertiary ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-global-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="global_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16"><path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16"><path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16"><path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path></svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-1 flex-shrink-0 color-bg-tertiary px-1 color-text-tertiary ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this organization" class="js-jump-to-badge-search-text-default d-none">
#         In this organization
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-1 flex-shrink-0 color-bg-tertiary px-1 color-text-tertiary ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </label>
# </form> </div>
# </div>
# </div>
# <a class="HeaderMenu-link flex-shrink-0 no-underline mr-3" data-ga-click="(Logged out) Header, clicked Sign in, text:sign-in" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header menu","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/google?page=1","user_id":null}}' data-hydro-click-hmac="a98e1b946674c992f752422cede7cedb3bb3915eff072063bed65133d6a59de5" href="/login?return_to=%2Fgoogle%3Fpage%3D1">
#           Sign in
#         </a>
# <nux-signup-candidates data-action="loaded:nux-signup-candidates#determineSignupAction" data-attribute-name="href" data-candidate-url="/join_next?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2F%3Corg-login%3E&amp;source=header">
# <a class="HeaderMenu-link flex-shrink-0 d-inline-block no-underline border color-border-tertiary rounded px-2 py-1" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header menu","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/google?page=1","user_id":null}}' data-hydro-click-hmac="a98e1b946674c992f752422cede7cedb3bb3915eff072063bed65133d6a59de5" data-target="nux-signup-candidates.signupAction" href="/join?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2F%3Corg-login%3E&amp;source=header">
#                 Sign up
#               </a>
# </nux-signup-candidates>
# </div>
# </div>
# </div>
# </header>
# </div>
# <div class="show-on-focus" id="start-of-content"></div>
# <div data-pjax-replace="" id="js-flash-container">
# <template class="js-flash-template">
# <div class="flash flash-full {{ className }}">
# <div class="container-lg px-2">
# <button aria-label="Dismiss this message" class="flash-close js-flash-close" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path></svg>
# </button>
# <div>{{ message }}</div>
# </div>
# </div>
# </template>
# </div>
# <include-fragment class="js-notification-shelf-include-fragment" data-base-src="https://github.com/notifications/beta/shelf"></include-fragment>
# <div class="application-main" data-commit-hovercards-enabled="" data-discussion-hovercards-enabled="" data-issue-and-pr-hovercards-enabled="">
# <main data-pjax-container="" id="js-pjax-container">
# <div itemscope="" itemtype="http://schema.org/Organization">
# <header class="pagehead orghead border-bottom-0 pt-0">
# <div class="container-lg pt-4 pt-lg-0 p-responsive clearfix">
# <div class="d-flex flex-wrap flex-items-start flex-md-items-center my-3">
# <div>
# <img alt="@google" class="avatar flex-shrink-0 mb-3 mr-3 mb-md-0 mr-md-4" height="100" itemprop="image" src="https://avatars.githubusercontent.com/u/1342004?s=200&amp;v=4" width="100"/>
# </div>
# <div class="flex-1">
# <h1 class="h2 lh-condensed">
#           Google
#         </h1>
# <div class="color-text-tertiary"><div>Google <g-emoji alias="heart" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/2764.png">❤️</g-emoji> Open Source</div></div>
# <div class="d-md-flex flex-items-center mt-2">
# <ul class="d-md-flex list-style-none f6 has-blog has-email">
# <li class="mr-md-3 v-align-middle color-text-primary my-2 my-md-0 css-truncate css-truncate-target" style="max-width: 230px">
# <svg aria-hidden="true" class="octicon octicon-link flex-shrink-0" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path></svg>
# <a class="color-text-primary" href="https://opensource.google/" itemprop="url" rel="nofollow" title="https://opensource.google/">https://opensource.google/</a>
# </li>
# <li class="mr-md-3 v-align-middle my-2 my-md-0 css-truncate css-truncate-target" style="max-width: 230px">
# ...
# <div class="Box-body">
# <a class="d-block color-text-primary" data-ga-click="Orgs, go to people, location:profile people module; text:People" href="/orgs/google/people">
# <span class="float-right f5 color-text-secondary">
# <span class="js-profile-member-count"></span>
# <svg aria-hidden="true" class="octicon octicon-chevron-right" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M6.22 3.22a.75.75 0 011.06 0l4.25 4.25a.75.75 0 010 1.06l-4.25 4.25a.75.75 0 01-1.06-1.06L9.94 8 6.22 4.28a.75.75 0 010-1.06z" fill-rule="evenodd"></path></svg>
# </span>
# <h4 class="f4 text-normal mb-3">People</h4>
# </a>
# <div class="clearfix d-flex flex-wrap" style="margin: -1px">
# <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/raggi/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/raggi">
# <img alt="@raggi" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/348?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/grantr/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/grantr">
# <img alt="@grantr" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/680?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/farcaller/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/farcaller">
# <img alt="@farcaller" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/693?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/haberman/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/haberman">
# <img alt="@haberman" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/1270?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/fserb/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/fserb">
# <img alt="@fserb" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/1587?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/rictic/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/rictic">
# <img alt="@rictic" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/1659?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/dustin/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/dustin">
# <img alt="@dustin" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/1779?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/dewitt/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/dewitt">
# <img alt="@dewitt" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/2736?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/snatchev/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/snatchev">
# <img alt="@snatchev" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/3312?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/evmar/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/evmar">
# <img alt="@evmar" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/3847?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/proppy/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/proppy">
# <img alt="@proppy" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/5268?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/olegshaldybin/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/olegshaldybin">
# <img alt="@olegshaldybin" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/8273?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/heathkit/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/heathkit">
# <img alt="@heathkit" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/9543?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/tjohns/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/tjohns">
# <img alt="@tjohns" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/9989?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/pwnall/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/pwnall">
# <img alt="@pwnall" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/11460?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/jkomoros/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/jkomoros">
# <img alt="@jkomoros" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/12029?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/brandonweeks/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/brandonweeks">
# <img alt="@brandonweeks" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/15869?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/d0k/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/d0k">
# <img alt="@d0k" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/16542?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/jskeet/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/jskeet">
# <img alt="@jskeet" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/17011?s=96&amp;v=4" width="48"/>
# </a> <a class="member-avatar" data-ga-click="Orgs, go to person, location:profile people module; text:username" data-hovercard-type="user" data-hovercard-url="/users/eatnumber1/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/eatnumber1">
# <img alt="@eatnumber1" class="avatar avatar-user" height="48" src="https://avatars.githubusercontent.com/u/17551?s=96&amp;v=4" width="48"/>
# </a>
# </div>
# </div>
# </div>
# <div class="py-3">
# <a class="d-flex flex-items-center" href="https://docs.github.com">
# <svg aria-hidden="true" class="octicon octicon-cpu mr-2 color-text-tertiary" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M6.5.75a.75.75 0 00-1.5 0V2H3.75A1.75 1.75 0 002 3.75V5H.75a.75.75 0 000 1.5H2v3H.75a.75.75 0 000 1.5H2v1.25c0 .966.784 1.75 1.75 1.75H5v1.25a.75.75 0 001.5 0V14h3v1.25a.75.75 0 001.5 0V14h1.25A1.75 1.75 0 0014 12.25V11h1.25a.75.75 0 000-1.5H14v-3h1.25a.75.75 0 000-1.5H14V3.75A1.75 1.75 0 0012.25 2H11V.75a.75.75 0 00-1.5 0V2h-3V.75zm5.75 11.75h-8.5a.25.25 0 01-.25-.25v-8.5a.25.25 0 01.25-.25h8.5a.25.25 0 01.25.25v8.5a.25.25 0 01-.25.25zM5.75 5a.75.75 0 00-.75.75v4.5c0 .414.336.75.75.75h4.5a.75.75 0 00.75-.75v-4.5a.75.75 0 00-.75-.75h-4.5zm.75 4.5v-3h3v3h-3z" fill-rule="evenodd"></path></svg> Developer Program Member
#           </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </main>
# </div>
# <div class="footer container-lg width-full p-responsive" role="contentinfo">
# <div class="position-relative d-flex flex-row-reverse flex-lg-row flex-wrap flex-lg-nowrap flex-justify-center flex-lg-justify-between pt-6 pb-2 mt-6 f6 color-text-secondary border-top color-border-secondary">
# <ul class="list-style-none d-flex flex-wrap col-12 col-lg-5 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mr-3 mr-lg-0">© 2021 GitHub, Inc.</li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to terms, text:terms" href="https://docs.github.com/en/github/site-policy/github-terms-of-service">Terms</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to privacy, text:privacy" href="https://docs.github.com/en/github/site-policy/github-privacy-statement">Privacy</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to security, text:security" href="https://github.com/security">Security</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to status, text:status" href="https://www.githubstatus.com/">Status</a></li>
# <li><a data-ga-click="Footer, go to help, text:Docs" href="https://docs.github.com">Docs</a></li>
# </ul>
# <a aria-label="Homepage" class="footer-octicon d-none d-lg-block mx-lg-4" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" height="24" version="1.1" viewbox="0 0 16 16" width="24"><path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path></svg>
# </a>
# <ul class="list-style-none d-flex flex-wrap col-12 col-lg-5 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to contact, text:contact" href="https://support.github.com">Contact GitHub</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to Pricing, text:Pricing" href="https://github.com/pricing">Pricing</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to api, text:api" href="https://docs.github.com">API</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to training, text:training" href="https://services.github.com">Training</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to blog, text:blog" href="https://github.blog">Blog</a></li>
# <li><a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a></li>
# </ul>
# </div>
# <div class="d-flex flex-justify-center pb-6">
# <span class="f6 color-text-tertiary"></span>
# </div>
# </div>
# <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path></svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path></svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <div class="js-stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path></svg>
# <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default color-text-primary hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path></svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
# </div>
# </div>
# </body>
# </html>

# %%
soup.select("[itemprop='name codeRepository']")
# Out:
# [<a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/earthenterprise/hovercard" href="/google/earthenterprise" itemprop="name codeRepository">
#              earthenterprise
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/clusterfuzz/hovercard" href="/google/clusterfuzz" itemprop="name codeRepository">
#              clusterfuzz
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/nearby-connections/hovercard" href="/google/nearby-connections" itemprop="name codeRepository">
#              nearby-connections
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/flatbuffers/hovercard" href="/google/flatbuffers" itemprop="name codeRepository">
#              flatbuffers
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/fhir/hovercard" href="/google/fhir" itemprop="name codeRepository">
#              fhir
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/iree/hovercard" href="/google/iree" itemprop="name codeRepository">
#              iree
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/site-kit-wp/hovercard" href="/google/site-kit-wp" itemprop="name codeRepository">
#              site-kit-wp
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/llvm-bazel/hovercard" href="/google/llvm-bazel" itemprop="name codeRepository">
#              llvm-bazel
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/vscode-bigquery/hovercard" href="/google/vscode-bigquery" itemprop="name codeRepository">
#              vscode-bigquery
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/closure-compiler/hovercard" href="/google/closure-compiler" itemprop="name codeRepository">
#              closure-compiler
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/ecclesia-machine-management/hovercard" href="/google/ecclesia-machine-management" itemprop="name codeRepository">
#              ecclesia-machine-management
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/xls/hovercard" href="/google/xls" itemprop="name codeRepository">
#              xls
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/proto-lens/hovercard" href="/google/proto-lens" itemprop="name codeRepository">
#              proto-lens
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/jax/hovercard" href="/google/jax" itemprop="name codeRepository">
#              jax
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/gvisor/hovercard" href="/google/gvisor" itemprop="name codeRepository">
#              gvisor
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/gazoo-device/hovercard" href="/google/gazoo-device" itemprop="name codeRepository">
#              gazoo-device
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/modernstorage/hovercard" href="/google/modernstorage" itemprop="name codeRepository">
#              modernstorage
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/pigweed/hovercard" href="/google/pigweed" itemprop="name codeRepository">
#              pigweed
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/web-stories-wp/hovercard" href="/google/web-stories-wp" itemprop="name codeRepository">
#              web-stories-wp
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/gtm-session-fetcher/hovercard" href="/google/gtm-session-fetcher" itemprop="name codeRepository">
#              gtm-session-fetcher
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/or-tools/hovercard" href="/google/or-tools" itemprop="name codeRepository">
#              or-tools
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/XNNPACK/hovercard" href="/google/XNNPACK" itemprop="name codeRepository">
#              XNNPACK
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/BIG-bench/hovercard" href="/google/BIG-bench" itemprop="name codeRepository">
#              BIG-bench
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/dagger/hovercard" href="/google/dagger" itemprop="name codeRepository">
#              dagger
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/kne/hovercard" href="/google/kne" itemprop="name codeRepository">
#              kne
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/megalista/hovercard" href="/google/megalista" itemprop="name codeRepository">
#              megalista
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/knative-gcp/hovercard" href="/google/knative-gcp" itemprop="name codeRepository">
#              knative-gcp
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/pytype/hovercard" href="/google/pytype" itemprop="name codeRepository">
#              pytype
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/it-cert-automation-practice/hovercard" href="/google/it-cert-automation-practice" itemprop="name codeRepository">
#              it-cert-automation-practice
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/CFU-Playground/hovercard" href="/google/CFU-Playground" itemprop="name codeRepository">
#              CFU-Playground
#  </a>]

# %%
soup.find_all('a', itemprop='name codeRepository')
# Out:
# [<a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/earthenterprise/hovercard" href="/google/earthenterprise" itemprop="name codeRepository">
#              earthenterprise
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/clusterfuzz/hovercard" href="/google/clusterfuzz" itemprop="name codeRepository">
#              clusterfuzz
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/nearby-connections/hovercard" href="/google/nearby-connections" itemprop="name codeRepository">
#              nearby-connections
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/flatbuffers/hovercard" href="/google/flatbuffers" itemprop="name codeRepository">
#              flatbuffers
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/fhir/hovercard" href="/google/fhir" itemprop="name codeRepository">
#              fhir
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/iree/hovercard" href="/google/iree" itemprop="name codeRepository">
#              iree
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/site-kit-wp/hovercard" href="/google/site-kit-wp" itemprop="name codeRepository">
#              site-kit-wp
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/llvm-bazel/hovercard" href="/google/llvm-bazel" itemprop="name codeRepository">
#              llvm-bazel
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/vscode-bigquery/hovercard" href="/google/vscode-bigquery" itemprop="name codeRepository">
#              vscode-bigquery
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/closure-compiler/hovercard" href="/google/closure-compiler" itemprop="name codeRepository">
#              closure-compiler
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/ecclesia-machine-management/hovercard" href="/google/ecclesia-machine-management" itemprop="name codeRepository">
#              ecclesia-machine-management
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/xls/hovercard" href="/google/xls" itemprop="name codeRepository">
#              xls
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/proto-lens/hovercard" href="/google/proto-lens" itemprop="name codeRepository">
#              proto-lens
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/jax/hovercard" href="/google/jax" itemprop="name codeRepository">
#              jax
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/gvisor/hovercard" href="/google/gvisor" itemprop="name codeRepository">
#              gvisor
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/gazoo-device/hovercard" href="/google/gazoo-device" itemprop="name codeRepository">
#              gazoo-device
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/modernstorage/hovercard" href="/google/modernstorage" itemprop="name codeRepository">
#              modernstorage
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/pigweed/hovercard" href="/google/pigweed" itemprop="name codeRepository">
#              pigweed
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/web-stories-wp/hovercard" href="/google/web-stories-wp" itemprop="name codeRepository">
#              web-stories-wp
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/gtm-session-fetcher/hovercard" href="/google/gtm-session-fetcher" itemprop="name codeRepository">
#              gtm-session-fetcher
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/or-tools/hovercard" href="/google/or-tools" itemprop="name codeRepository">
#              or-tools
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/XNNPACK/hovercard" href="/google/XNNPACK" itemprop="name codeRepository">
#              XNNPACK
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/BIG-bench/hovercard" href="/google/BIG-bench" itemprop="name codeRepository">
#              BIG-bench
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/dagger/hovercard" href="/google/dagger" itemprop="name codeRepository">
#              dagger
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/kne/hovercard" href="/google/kne" itemprop="name codeRepository">
#              kne
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/megalista/hovercard" href="/google/megalista" itemprop="name codeRepository">
#              megalista
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/knative-gcp/hovercard" href="/google/knative-gcp" itemprop="name codeRepository">
#              knative-gcp
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/pytype/hovercard" href="/google/pytype" itemprop="name codeRepository">
#              pytype
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/it-cert-automation-practice/hovercard" href="/google/it-cert-automation-practice" itemprop="name codeRepository">
#              it-cert-automation-practice
#  </a>,
#  <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/CFU-Playground/hovercard" href="/google/CFU-Playground" itemprop="name codeRepository">
#              CFU-Playground
#  </a>]

# %%
soup.find_all('a', itemprop='name codeRepository')[0]
# Out:
# <a class="d-inline-block" data-hovercard-type="repository" data-hovercard-url="/google/earthenterprise/hovercard" href="/google/earthenterprise" itemprop="name codeRepository">
#             earthenterprise
# </a>

# %%
soup.find_all('a', itemprop='name codeRepository')[0].get('href')
# Out:
# '/google/earthenterprise'

# %%
link_suffix = soup.find_all('a', itemprop='name codeRepository')[0].get('href')

# %%
def get_githubpgs():
    """
    This function will create a list of all the url pages in the google repos section
    """
    urls = []
    for i in range(1,68):
        
        url = f'https://https://github.com/google?page={i}'
        urls.append(url)
    return urls

# %%
def get_repo_links():
    """
    This function will concat a base url with the repo suffix
    and create a list of all appended repo links on a single page.
    """
    repos = []
    for i in range(0,30):
        link_suffix = soup.find_all('a', itemprop='name codeRepository')[i].get('href')
        link  = f'https://github.com/{link_suffix}'
        repos.append(link)
    return repos

# %%
repos1 = get_repo_links()
repos1
# Out:
# ['https://github.com//google/earthenterprise',
#  'https://github.com//google/clusterfuzz',
#  'https://github.com//google/nearby-connections',
#  'https://github.com//google/flatbuffers',
#  'https://github.com//google/fhir',
#  'https://github.com//google/iree',
#  'https://github.com//google/site-kit-wp',
#  'https://github.com//google/llvm-bazel',
#  'https://github.com//google/vscode-bigquery',
#  'https://github.com//google/closure-compiler',
#  'https://github.com//google/ecclesia-machine-management',
#  'https://github.com//google/xls',
#  'https://github.com//google/proto-lens',
#  'https://github.com//google/jax',
#  'https://github.com//google/gvisor',
#  'https://github.com//google/gazoo-device',
#  'https://github.com//google/modernstorage',
#  'https://github.com//google/pigweed',
#  'https://github.com//google/web-stories-wp',
#  'https://github.com//google/gtm-session-fetcher',
#  'https://github.com//google/or-tools',
#  'https://github.com//google/XNNPACK',
#  'https://github.com//google/BIG-bench',
#  'https://github.com//google/dagger',
#  'https://github.com//google/kne',
#  'https://github.com//google/megalista',
#  'https://github.com//google/knative-gcp',
#  'https://github.com//google/pytype',
#  'https://github.com//google/it-cert-automation-practice',
#  'https://github.com//google/CFU-Playground']

# %%
def souper(url):
    """
    
    """
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
    response = requests.get(url, headers=headers)
    
    html = response.text
    soup = BeautifulSoup(html)
    
    return soup

# %%
def get_all_repo_links():
    """
    
    """
    repo_links = []
    
    urls = get_githubpgs()
    
    for url in urls:
        soup = souper(url)
        
        repos = get_repo_links()
        repo_links.append(repos)
    
    return repo_links

# %%
repo_links = get_all_repo_links()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# /usr/local/anaconda3/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     308         # Add certificate verification
# --> 309         conn = self._new_conn()
#     310         hostname = self.host
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     170         except SocketError as e:
# --> 171             raise NewConnectionError(
#     172                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7facdd724940>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     445         if new_retry.is_exhausted():
# --> 446             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     447
#
# MaxRetryError: HTTPSConnectionPool(host='https', port=443): Max retries exceeded with url: //github.com/google?page=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7facdd724940>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-51-534c96b24708> in <module>
# ----> 1 repo_links = get_all_repo_links()
#
# <ipython-input-50-46d056b63d7b> in get_all_repo_links()
#       8
#       9     for url in urls:
# ---> 10         soup = souper(url)
#      11
#      12         repos = get_repo_links()
#
# <ipython-input-49-0c1d8b21eef7> in souper(url)
#       4     """
#       5     headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
# ----> 6     response = requests.get(url, headers=headers)
#       7
#       8     html = response.text
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='https', port=443): Max retries exceeded with url: //github.com/google?page=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7facdd724940>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
